# %% [markdown]
# <a href="https://colab.research.google.com/github/mjcolebank/Colebank_REU_2026/blob/main/100k_Test/EarlyFusionBCNN_Standardized(clean).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Early Fusion BCNN Standardized

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/REU ECG Analysis
# !ls
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/REU ECG Analysis
# BCNN		    ECG_waveforms_1K.npy      outputs
# ECG_metrics_1K.npy  EchoNext_EchoData_5K.csv  PaperFigures

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import time # Import time for sleep in retry mechanism

import sympy

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from scipy.signal import butter, filtfilt
from sklearn.preprocessing import StandardScaler
from sklearn.impute import KNNImputer
from sklearn.metrics import (
    roc_auc_score, precision_recall_curve, auc, roc_curve,
    brier_score_loss, confusion_matrix, ConfusionMatrixDisplay
)
from sklearn.model_selection import train_test_split

# !pip install blitz-bayesian-pytorch
from blitz.modules import BayesianLinear, BayesianConv1d
from blitz.utils import variational_estimator

# ──────────────────────────────────────────────────────────────────────
# 0. CONFIGURATION & HYPERPARAMETERS
# ──────────────────────────────────────────────────────────────────────
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

PRIOR_SIGMA_1 = 2.0
PRIOR_SIGMA_2 = 0.0025
PRIOR_PI = 1.0
POSTERIOR_RHO_INIT = -5.0

CATEGORICAL_COLS = ["race_ethnicity", "sex"]
CONTINUOUS_COLS = [
    "age_at_ecg", "ventricular_rate", "atrial_rate",
    "pr_interval", "qrs_duration", "qt_corrected"
]
ALL_DEMO_COLS = CATEGORICAL_COLS + CONTINUOUS_COLS

# ──────────────────────────────────────────────────────────────────────
# 1. SIGNAL PROCESSING & SIGNAL FILTERING
# ──────────────────────────────────────────────────────────────────────
ECG_SAMPLING_RATE_HZ = 500   # adjust to your true acquisition rate
FILTER_LOW_HZ = 0.5          # removes baseline wander
FILTER_HIGH_HZ = 40.0        # removes high-frequency EMG / powerline noise
FILTER_ORDER = 4

def bandpass_filter_ecg(signal_array, fs=ECG_SAMPLING_RATE_HZ,
                         low=FILTER_LOW_HZ, high=FILTER_HIGH_HZ, order=FILTER_ORDER):
    nyquist = 0.5 * fs
    b, a = butter(order, [low / nyquist, high / nyquist], btype="band")
    filtered = filtfilt(b, a, signal_array, axis=0)   # time is axis 0 for a single [L, C] sample
    return filtered.astype(np.float32)

# ──────────────────────────────────────────────────────────────────────
# 2. DEMOGRAPHIC PREPROCESSING
# ──────────────────────────────────────────────────────────────────────
def preprocess_demographics(df, scaler=None, imputer=None, categories=None, knn_k=5, fit=True):
    df = df[ALL_DEMO_COLS].copy()

    if categories is None:
        if not fit:
            raise ValueError("`categories` dictionary map must be provided when fit=False.")
        categories = {col: df[col].astype("category").cat.categories for col in CATEGORICAL_COLS}

    cat_codes = pd.DataFrame(index=df.index)
    for col in CATEGORICAL_COLS:
        cat_codes[col] = pd.Categorical(df[col], categories=categories[col]).codes
    cat_codes = cat_codes.replace(-1, np.nan)

    cont_part = df[CONTINUOUS_COLS].astype(float)
    imputer_input = pd.concat([cat_codes, cont_part], axis=1)

    if imputer is None:
        if not fit:
            raise ValueError("`imputer` object instance must be explicitly provided when fit=False.")
        imputer = KNNImputer(n_neighbors=knn_k)

    if fit:
        imputed = imputer.fit_transform(imputer_input)
    else:
        imputed = imputer.transform(imputer_input)

    imputed_df = pd.DataFrame(imputed, columns=ALL_DEMO_COLS, index=df.index)

    for col in CATEGORICAL_COLS:
        cats = categories[col]
        codes_rounded = imputed_df[col].round().astype(int).clip(0, len(cats) - 1)
        imputed_df[col] = pd.Categorical.from_codes(codes_rounded, categories=cats)

    ohe_df = pd.get_dummies(imputed_df, columns=CATEGORICAL_COLS, dtype=float)
    feature_names = list(ohe_df.columns)

    if scaler is None:
        if not fit:
            raise ValueError("`scaler` must be provided when fit=False.")
        scaler = StandardScaler()

    cont_indices = [feature_names.index(c) for c in CONTINUOUS_COLS]
    arr = ohe_df.values.astype(np.float32)

    if fit:
        arr[:, cont_indices] = scaler.fit_transform(arr[:, cont_indices])
    else:
        arr[:, cont_indices] = scaler.transform(arr[:, cont_indices])

    return arr, scaler, imputer, categories, feature_names

# ──────────────────────────────────────────────────────────────────────
# 3. PYTORCH DATA STRUCTURING
# ──────────────────────────────────────────────────────────────────────
class FusedDataset(Dataset):
    def __init__(self, X_ts, X_demo, y):
        assert len(X_ts) == len(X_demo) == len(y), "Length mismatch across tensor targets."
        self.X_ts = torch.tensor(X_ts, dtype=torch.float32)
        self.X_demo = torch.tensor(X_demo, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long)

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X_ts[idx], self.X_demo[idx], self.y[idx]

# ──────────────────────────────────────────────────────────────────────
# 4. BAYESIAN NETWORK ARCHITECTURE
# ──────────────────────────────────────────────────────────────────────
class BayesianFiLMLayer(nn.Module):
    def __init__(self, demo_embed_dim, num_channels):
        super().__init__()
        self.film_proj = BayesianLinear(
            demo_embed_dim, 2 * num_channels,
            prior_sigma_1=PRIOR_SIGMA_1, prior_sigma_2=PRIOR_SIGMA_2, prior_pi=PRIOR_PI,
            posterior_rho_init=POSTERIOR_RHO_INIT
        )

    def forward(self, h, demo_embed):
        params = self.film_proj(demo_embed)
        gamma, beta = params.chunk(2, dim=-1)
        return gamma.unsqueeze(-1) * h + beta.unsqueeze(-1)

class BayesianFiLMConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, padding, pool_size, demo_embed_dim, pool_type="avg"):
        super().__init__()
        self.conv = BayesianConv1d(
            in_channels, out_channels, kernel_size=kernel_size, padding=padding,
            prior_sigma_1=PRIOR_SIGMA_1, prior_sigma_2=PRIOR_SIGMA_2, prior_pi=PRIOR_PI,
            posterior_rho_init=POSTERIOR_RHO_INIT
        )
        self.bn = nn.BatchNorm1d(out_channels)
        self.film = BayesianFiLMLayer(demo_embed_dim, out_channels)
        self.act = nn.ReLU()
        self.pool = nn.AdaptiveAvgPool1d(1) if pool_type == "gap" else nn.AvgPool1d(kernel_size=pool_size)

    def forward(self, x, demo_embed):
        return self.pool(self.act(self.film(self.bn(self.conv(x)), demo_embed)))

@variational_estimator
class BayesianHeartDiseaseNet(nn.Module):
    def __init__(self, sequence_length, in_channels, demo_dim, num_classes=2, demo_embed_dim=16):
        super().__init__()
        def blinear(in_f, out_f):
            return BayesianLinear(
                in_f, out_f, prior_sigma_1=PRIOR_SIGMA_1, prior_sigma_2=PRIOR_SIGMA_2,
                prior_pi=PRIOR_PI, posterior_rho_init=POSTERIOR_RHO_INIT
            )

        self.demo_encoder = nn.Sequential(blinear(demo_dim, demo_embed_dim), nn.ReLU())
        self.block1 = BayesianFiLMConvBlock(in_channels, 16, kernel_size=15, padding=7, pool_size=10, demo_embed_dim=demo_embed_dim, pool_type="avg")
        self.block2 = BayesianFiLMConvBlock(16, 32, kernel_size=9, padding=4, pool_size=10, demo_embed_dim=demo_embed_dim, pool_type="avg")
        self.block3 = BayesianFiLMConvBlock(32, 32, kernel_size=5, padding=2, pool_size=None, demo_embed_dim=demo_embed_dim, pool_type="gap")

        with torch.no_grad():
            dummy_ts = torch.zeros(1, in_channels, sequence_length)
            dummy_demo = torch.zeros(1, demo_embed_dim)
            x = self.block3(self.block2(self.block1(dummy_ts, dummy_demo), dummy_demo), dummy_demo)
            flat_sz = x.shape[1] * x.shape[2]

        self.head = nn.Sequential(nn.Flatten(), blinear(flat_sz, 32), nn.ReLU(), blinear(32, num_classes))

    def forward(self, x_ts, x_demo):
        demo_embed = self.demo_encoder(x_demo)
        return self.head(self.block3(self.block2(self.block1(x_ts, demo_embed), demo_embed), demo_embed))

# ──────────────────────────────────────────────────────────────────────
# 5. TRAINING ROUTINE
# ──────────────────────────────────────────────────────────────────────
def train_bayesian_classifier(model, train_loader, val_loader, epochs=60, learning_rate=1e-4, sample_nbr=3):
    model = model.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", factor=0.5, patience=3)
    n_train = len(train_loader.dataset)

    for epoch in range(epochs):
        model.train()
        for X_ts_b, X_demo_b, y_b in train_loader:
            X_ts_b, X_demo_b, y_b = X_ts_b.to(device), X_demo_b.to(device), y_b.to(device)
            X_ts_b += 0.05 * torch.randn_like(X_ts_b)

            optimizer.zero_grad()
            nll = 0.0
            for _ in range(sample_nbr):
                logits = model(X_ts_b, X_demo_b)
                nll += criterion(logits, y_b)

            loss = (nll / sample_nbr) + (model.nn_kl_divergence() / n_train)
            loss.backward()
            optimizer.step()

        model.eval()
        val_loss, val_total = 0.0, 0
        with torch.no_grad():
            for X_ts_v, X_demo_v, y_v in val_loader:
                X_ts_v, X_demo_v, y_v = X_ts_v.to(device), X_demo_v.to(device), y_v.to(device)
                probs_accum = sum(torch.softmax(model(X_ts_v, X_demo_v), dim=1) for _ in range(10)) / 10
                val_loss += criterion(torch.log(probs_accum + 1e-8), y_v).item() * X_ts_v.shape[0]
                val_total += X_ts_v.shape[0]

        scheduler.step(val_loss / val_total)

# ──────────────────────────────────────────────────────────────────────
# 6. PERFORMANCE METRICS GENERATION & CALIBRATION ESTIMATION
# ──────────────────────────────────────────────────────────────────────
def calculate_calibration_error(probs, labels, bins=10):
    bin_boundaries = np.linspace(0, 1, bins + 1)
    ece = 0.0
    for i in range(bins):
        # Fix: Correctly unpack bin_lower and bin_upper
        bin_lower, bin_upper = bin_boundaries[i], bin_boundaries[i + 1]
        in_bin = (probs >= bin_lower) & (probs < bin_upper)
        prop_in_bin = np.mean(in_bin)
        if prop_in_bin > 0:
            accuracy_in_bin = np.mean(labels[in_bin] == (probs[in_bin] >= 0.5))
            avg_confidence_in_bin = np.mean(probs[in_bin])
            ece += prop_in_bin * np.abs(avg_confidence_in_bin - accuracy_in_bin)
    return ece

def get_predictions_and_labels(model, loader, sample_nbr=50):
    model.eval()
    all_probs, all_labels = [], []
    all_nll = 0.0
    criterion = nn.CrossEntropyLoss(reduction='sum')

    with torch.no_grad():
        for X_ts_b, X_demo_b, y_b in loader:
            X_ts_b, X_demo_b = X_ts_b.to(device), X_demo_b.to(device)
            pass_logits = torch.stack([model(X_ts_b, X_demo_b) for _ in range(sample_nbr)], dim=0)

            # Average raw probabilities across stochastic forward steps
            pass_probs = torch.softmax(pass_logits, dim=-1)
            mean_probs = pass_probs.mean(dim=0)

            # Calculate Cross Entropy Loss (Negative Log-Likelihood) over averaged probabilities
            all_nll += criterion(torch.log(mean_probs + 1e-8), y_b.to(device)).item()

            all_probs.extend(mean_probs[:, 1].cpu().numpy())
            all_labels.extend(y_b.numpy())

    return np.array(all_probs), np.array(all_labels), all_nll / len(loader.dataset)

def generate_and_display_comparative_metrics(model, train_loader, test_loader, sample_nbr=50):
    """
    Computes summary metrics for train vs. test, prints the structured side-by-side
    comparison table, and renders integrated metric evaluation profiles.
    """
    # Evaluate datasets
    train_probs, train_labels, train_nll = get_predictions_and_labels(model, train_loader, sample_nbr)
    test_probs, test_labels, test_nll = get_predictions_and_labels(model, test_loader, sample_nbr)

    train_preds = (train_probs >= 0.5).astype(int)
    test_preds = (test_probs >= 0.5).astype(int)

    # Structural calculations
    metrics_map = {
        "accuracy": (np.mean(train_preds == train_labels), np.mean(test_preds == test_labels)),
        "auroc": (roc_auc_score(train_labels, train_probs), roc_auc_score(test_labels, test_probs)),
        "auprc": (None, None), # Calculated directly below using sklearn auc
        "brier_score": (brier_score_loss(train_labels, train_probs), brier_score_loss(test_labels, test_probs)),
        "negative_log_likelihood": (train_nll, test_nll),
        "expected_calibration_error": (calculate_calibration_error(train_probs, train_labels), calculate_calibration_error(test_probs, test_labels))
    }

    # Train curve values
    train_precision, train_recall, _ = precision_recall_curve(train_labels, train_probs)
    train_fpr, train_tpr, _ = roc_curve(train_labels, train_probs)
    metrics_map["auprc"] = (auc(train_recall, train_precision), metrics_map["auprc"][1])

    # Test curve values
    test_precision, test_recall, _ = precision_recall_curve(test_labels, test_probs)
    test_fpr, test_tpr, _ = roc_curve(test_labels, test_probs)
    metrics_map["auprc"] = (metrics_map["auprc"][0], auc(test_recall, test_precision))

    # Confusion Matrix decompositions
    tn_tr, fp_tr, fn_tr, tp_tr = confusion_matrix(train_labels, train_preds).ravel()
    tn_te, fp_te, fn_te, tp_te = confusion_matrix(test_labels, test_preds).ravel()

    metrics_map["tn"] = (float(tn_tr), float(tn_te))
    metrics_map["fp"] = (float(fp_tr), float(fp_te))
    metrics_map["fn"] = (float(fn_tr), float(fn_te))
    metrics_map["tp"] = (float(tp_tr), float(tp_te))

    # ── PRINT EXACT ALIGNED TEXT TABLE ──
    print("\nClassification metrics (train vs. test):")
    print(f"{'':<28} {'train':<10} {'test':<10}")
    for k, v in metrics_map.items():
        print(f"{k:<28} {v[0]:.6f}   {v[1]:.6f}")

    # ── PLOT ANALYSIS GRAPH PROFILES ──
    fig, ax = plt.subplots(1, 3, figsize=(16, 4.5))

    # 1. ROC Curves
    ax[0].plot(train_fpr, train_tpr, color='teal', lw=2, label=f'Train ROC (AUC = {metrics_map["auroc"][0]:.3f})')
    ax[0].plot(test_fpr, test_tpr, color='orange', lw=2, label=f'Test ROC (AUC = {metrics_map["auroc"][1]:.3f})')
    ax[0].plot([0, 1], [0, 1], color='navy', linestyle='--')
    ax[0].set_xlabel('False Positive Rate')
    ax[0].set_ylabel('True Positive Rate')
    ax[0].set_title('Receiver Operating Characteristic (ROC) Curve')
    ax[0].legend(loc='lower right')

    # 2. Precision-Recall Curves
    ax[1].plot(train_recall, train_precision, color='teal', lw=2, label=f'Train PR (AUC = {metrics_map["auprc"][0]:.3f})')
    ax[1].plot(test_recall, test_precision, color='orange', lw=2, label=f'Test PR (AUC = {metrics_map["auprc"][1]:.3f})')
    ax[1].set_xlabel('Recall')
    ax[1].set_ylabel('Precision')
    ax[1].set_title('Precision-Recall (PR) Curve')
    ax[1].legend(loc='lower left')

    # 3. Consolidated Confusion Matrix (Test Split)
    cm_test = confusion_matrix(test_labels, test_preds)
    ConfusionMatrixDisplay(confusion_matrix=cm_test, display_labels=["No SHD", "SHD"]).plot(ax=ax[2], cmap="Blues", values_format="d")
    ax[2].set_title("Confusion Matrix (Holdout Test Split)")

    plt.tight_layout()
    plt.show()

# ──────────────────────────────────────────────────────────────────────
# 7. EXECUTION PIPELINE EXECUTION
# ──────────────────────────────────────────────────────────────────────
if __name__ == "__main__":
    print("Beginning execution pipeline...")

    # The base path should be set relative to the mounted Google Drive directory.
    # Since the previous cell performed `%cd /content/drive/MyDrive/REU ECG Analysis`,
    # the files are now in the current working directory.

    # ── STEP A: DATA INGESTION ────────────────────────────────────────
    ecg_path = 'ECG_waveforms_1K.npy'
    echo_path = 'EchoNext_EchoData_5K.csv'

    X_raw = None
    echo_df = None
    max_retries = 5
    retry_delay = 5 # seconds

    for attempt in range(max_retries):
        try:
            if not os.path.exists(ecg_path):
                print(f"ERROR: ECG waveform file not found at {ecg_path}")
                raise FileNotFoundError(f"ECG file not found: {ecg_path}")
            if not os.path.exists(echo_path):
                print(f"ERROR: Echo data file not found at {echo_path}")
                raise FileNotFoundError(f"Echo file not found: {echo_path}")

            X_raw = np.load(ecg_path)[:1000]
            echo_df = pd.read_csv(echo_path).iloc[:1000].reset_index(drop=True)
            print("Files loaded successfully.")
            break # Exit loop if successful
        except FileNotFoundError as e:
            print(f"Attempt {attempt + 1}/{max_retries}: {e}. Retrying in {retry_delay} seconds...")
            time.sleep(retry_delay)
        except Exception as e:
            print(f"An unexpected error occurred: {e}. Retrying in {retry_delay} seconds...")
            time.sleep(retry_delay)
    else:
        # This block executes if the loop completes without a 'break'
        raise RuntimeError("Failed to load required data files after multiple retries.")

    y_raw = echo_df['shd_moderate_or_greater_flag'].to_numpy()

    # ── STEP B: WAVEFORM PRE-FILTERING ──────────────────────────────
    X_filtered = np.array([bandpass_filter_ecg(x, fs=250) for x in X_raw])
    X_ts = np.swapaxes(X_filtered, 1, 2)

    # ── STEP C: DATASET PARTITIONING ──
    total_indices = np.arange(len(y_raw))

    rem_indices, test_indices = train_test_split(
        total_indices, test_size=0.10, random_state=RANDOM_SEED, stratify=y_raw
    )
    train_indices, val_indices = train_test_split(
        rem_indices, test_size=0.20, random_state=RANDOM_SEED, stratify=y_raw[rem_indices]
    )

    # ── STEP D: TRANSFORM DEMOGRAPHICS ──
    demo_df_train_val = echo_df.iloc[rem_indices].copy()
    demo_df_test = echo_df.iloc[test_indices].copy()

    X_demo_train_val, scaler, imputer, categories, feature_names = preprocess_demographics(
        demo_df_train_val, fit=True
    )
    X_demo_test, _, _, _, _ = preprocess_demographics(
        demo_df_test, scaler=scaler, imputer=imputer, categories=categories, fit=False
    )

    rem_global_to_local_map = {global_idx: local_idx for local_idx, global_idx in enumerate(rem_indices)}

    train_local_indices_in_X_demo_train_val = [rem_global_to_local_map[idx] for idx in train_indices]
    val_local_indices_in_X_demo_train_val = [rem_global_to_local_map[idx] for idx in val_indices]

    X_demo_train = X_demo_train_val[train_local_indices_in_X_demo_train_val]
    X_demo_val = X_demo_train_val[val_local_indices_in_X_demo_train_val]
    X_ts_train, X_ts_val, X_ts_test = X_ts[train_indices], X_ts[val_indices], X_ts[test_indices]
    y_train, y_val, y_test = y_raw[train_indices], y_raw[val_indices], y_raw[test_indices]

    # Create Dataloaders
    train_loader = DataLoader(FusedDataset(X_ts_train, X_demo_train, y_train), batch_size=32, shuffle=False)
    val_loader = DataLoader(FusedDataset(X_ts_val, X_demo_val, y_val), batch_size=128, shuffle=False)
    test_loader = DataLoader(FusedDataset(X_ts_test, X_demo_test, y_test), batch_size=128, shuffle=False)

    # ── STEP E: INITIALIZE & TRAIN THE MODEL ──────────────────────────
    model = BayesianHeartDiseaseNet(
        sequence_length=X_ts.shape[2], in_channels=X_ts.shape[1],
        demo_dim=X_demo_train.shape[1], num_classes=2, demo_embed_dim=32
    )

    print("Training model...")
    train_bayesian_classifier(model, train_loader, val_loader, epochs=60, learning_rate=1e-4)

    torch.manual_seed(RANDOM_SEED)

    # ── STEP F: PRINT SAMPLE INDIVIDUAL INFERENCE RECORDS ─────────────
    print("\n===== Individual Test Sample Inference Profiles ====")
    model.eval()
    sample_counter = 0

    with torch.no_grad():
        for X_ts_b, X_demo_b, y_b in test_loader:
            X_ts_b, X_demo_b = X_ts_b.to(device), X_demo_b.to(device)
            pass_logits = torch.stack([model(X_ts_b, X_demo_b) for _ in range(50)], dim=0)
            pass_probs = torch.softmax(pass_logits, dim=-1).cpu().numpy()

            mean_probs = pass_probs.mean(axis=0)
            std_probs = pass_probs.std(axis=0)

            for idx in range(X_ts_b.size(0)):
                true_val = y_b[idx].item()
                pred_val = np.argmax(mean_probs[idx])
                confidence = mean_probs[idx][pred_val]
                uncertainty = std_probs[idx][pred_val]
                global_df_idx = test_indices[sample_counter]

                print(f"Sample {sample_counter:03d} (DF Index: {global_df_idx:03d}) | "
                      f"True: {true_val} | Pred: {pred_val} | "
                      f"Confidence: {confidence:.4f} | Uncertainty (Std): {uncertainty:.4f}")
                sample_counter += 1

    # ── STEP G: SYSTEM METRICS ANALYSIS VISUALIZATIONS ────────────────
    generate_and_display_comparative_metrics(model, train_loader, test_loader, sample_nbr=50)
# Out:
# Requirement already satisfied: blitz-bayesian-pytorch in /usr/local/lib/python3.12/dist-packages (0.2.8)
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from blitz-bayesian-pytorch) (2.11.0+cu128)
# Requirement already satisfied: torchvision>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from blitz-bayesian-pytorch) (0.26.0+cu128)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from blitz-bayesian-pytorch) (2.0.2)
# Requirement already satisfied: scikit-learn>=0.22.2 in /usr/local/lib/python3.12/dist-packages (from blitz-bayesian-pytorch) (1.6.1)
# Requirement already satisfied: pillow>=7.1 in /usr/local/lib/python3.12/dist-packages (from blitz-bayesian-pytorch) (11.3.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.2->blitz-bayesian-pytorch) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.2->blitz-bayesian-pytorch) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.2->blitz-bayesian-pytorch) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->blitz-bayesian-pytorch) (3.29.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->blitz-bayesian-pytorch) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->blitz-bayesian-pytorch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->blitz-bayesian-pytorch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->blitz-bayesian-pytorch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->blitz-bayesian-pytorch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->blitz-bayesian-pytorch) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->blitz-bayesian-pytorch) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->blitz-bayesian-pytorch) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->blitz-bayesian-pytorch) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->blitz-bayesian-pytorch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->blitz-bayesian-pytorch) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->blitz-bayesian-pytorch) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->blitz-bayesian-pytorch) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->blitz-bayesian-pytorch) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->blitz-bayesian-pytorch) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->blitz-bayesian-pytorch) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->blitz-bayesian-pytorch) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->blitz-bayesian-pytorch) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->blitz-bayesian-pytorch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->blitz-bayesian-pytorch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->blitz-bayesian-pytorch) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->blitz-bayesian-pytorch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->blitz-bayesian-pytorch) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->blitz-bayesian-pytorch) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.7.0->blitz-bayesian-pytorch) (1.5.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.7.0->blitz-bayesian-pytorch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.7.0->blitz-bayesian-pytorch) (3.0.3)
# Using device: cuda
# Beginning execution pipeline...
# Files loaded successfully.
# Training model...
#
# ===== Individual Test Sample Inference Profiles ====
# Sample 000 (DF Index: 477) | True: 1 | Pred: 0 | Confidence: 0.5244 | Uncertainty (Std): 0.0415
# Sample 001 (DF Index: 837) | True: 1 | Pred: 1 | Confidence: 0.9998 | Uncertainty (Std): 0.0006
# Sample 002 (DF Index: 302) | True: 1 | Pred: 1 | Confidence: 0.9579 | Uncertainty (Std): 0.0148
# Sample 003 (DF Index: 405) | True: 0 | Pred: 0 | Confidence: 0.5659 | Uncertainty (Std): 0.0386
# Sample 004 (DF Index: 333) | True: 1 | Pred: 1 | Confidence: 0.8973 | Uncertainty (Std): 0.0587
# Sample 005 (DF Index: 332) | True: 1 | Pred: 1 | Confidence: 0.7958 | Uncertainty (Std): 0.0370
# Sample 006 (DF Index: 886) | True: 0 | Pred: 1 | Confidence: 0.5014 | Uncertainty (Std): 0.1190
# Sample 007 (DF Index: 730) | True: 0 | Pred: 0 | Confidence: 0.6067 | Uncertainty (Std): 0.0269
# Sample 008 (DF Index: 775) | True: 0 | Pred: 1 | Confidence: 0.9473 | Uncertainty (Std): 0.0374
# Sample 009 (DF Index: 741) | True: 0 | Pred: 0 | Confidence: 0.6448 | Uncertainty (Std): 0.0490
# Sample 010 (DF Index: 601) | True: 0 | Pred: 0 | Confidence: 0.5365 | Uncertainty (Std): 0.0979
# Sample 011 (DF Index: 732) | True: 0 | Pred: 0 | Confidence: 0.5763 | Uncertainty (Std): 0.0305
# Sample 012 (DF Index: 195) | True: 1 | Pred: 0 | Confidence: 0.6188 | Uncertainty (Std): 0.0398
# Sample 013 (DF Index: 112) | True: 1 | Pred: 1 | Confidence: 0.6143 | Uncertainty (Std): 0.0707
# Sample 014 (DF Index: 796) | True: 1 | Pred: 1 | Confidence: 0.5629 | Uncertainty (Std): 0.0478
# Sample 015 (DF Index: 486) | True: 1 | Pred: 1 | Confidence: 0.5084 | Uncertainty (Std): 0.1268
# Sample 016 (DF Index: 827) | True: 0 | Pred: 0 | Confidence: 0.8061 | Uncertainty (Std): 0.0183
# Sample 017 (DF Index: 977) | True: 1 | Pred: 1 | Confidence: 0.7326 | Uncertainty (Std): 0.0306
# Sample 018 (DF Index: 181) | True: 1 | Pred: 0 | Confidence: 0.5073 | Uncertainty (Std): 0.0910
# Sample 019 (DF Index: 890) | True: 1 | Pred: 1 | Confidence: 0.9962 | Uncertainty (Std): 0.0048
# Sample 020 (DF Index: 800) | True: 0 | Pred: 0 | Confidence: 0.7020 | Uncertainty (Std): 0.0324
# Sample 021 (DF Index: 150) | True: 0 | Pred: 0 | Confidence: 0.5229 | Uncertainty (Std): 0.0363
# Sample 022 (DF Index: 403) | True: 0 | Pred: 0 | Confidence: 0.7572 | Uncertainty (Std): 0.0285
# Sample 023 (DF Index: 972) | True: 1 | Pred: 1 | Confidence: 0.5624 | Uncertainty (Std): 0.1106
# Sample 024 (DF Index: 597) | True: 1 | Pred: 1 | Confidence: 0.6489 | Uncertainty (Std): 0.0701
# Sample 025 (DF Index: 463) | True: 1 | Pred: 1 | Confidence: 0.9862 | Uncertainty (Std): 0.0092
# Sample 026 (DF Index: 038) | True: 1 | Pred: 1 | Confidence: 0.7264 | Uncertainty (Std): 0.0385
# Sample 027 (DF Index: 661) | True: 0 | Pred: 1 | Confidence: 0.9937 | Uncertainty (Std): 0.0076
# Sample 028 (DF Index: 806) | True: 1 | Pred: 0 | Confidence: 0.7380 | Uncertainty (Std): 0.0255
# Sample 029 (DF Index: 535) | True: 1 | Pred: 0 | Confidence: 0.6694 | Uncertainty (Std): 0.0340
# Sample 030 (DF Index: 206) | True: 0 | Pred: 0 | Confidence: 0.6749 | Uncertainty (Std): 0.0154
# Sample 031 (DF Index: 537) | True: 1 | Pred: 1 | Confidence: 0.5707 | Uncertainty (Std): 0.0868
# Sample 032 (DF Index: 298) | True: 1 | Pred: 1 | Confidence: 0.6684 | Uncertainty (Std): 0.1340
# Sample 033 (DF Index: 933) | True: 1 | Pred: 1 | Confidence: 0.7831 | Uncertainty (Std): 0.0685
# Sample 034 (DF Index: 891) | True: 1 | Pred: 0 | Confidence: 0.9754 | Uncertainty (Std): 0.0098
# Sample 035 (DF Index: 746) | True: 1 | Pred: 1 | Confidence: 1.0000 | Uncertainty (Std): 0.0000
# Sample 036 (DF Index: 742) | True: 1 | Pred: 1 | Confidence: 0.8194 | Uncertainty (Std): 0.0674
# Sample 037 (DF Index: 056) | True: 1 | Pred: 1 | Confidence: 0.9738 | Uncertainty (Std): 0.0167
# Sample 038 (DF Index: 419) | True: 1 | Pred: 1 | Confidence: 0.5442 | Uncertainty (Std): 0.0460
# Sample 039 (DF Index: 936) | True: 0 | Pred: 0 | Confidence: 0.6872 | Uncertainty (Std): 0.0231
# Sample 040 (DF Index: 636) | True: 1 | Pred: 1 | Confidence: 0.5262 | Uncertainty (Std): 0.1090
# Sample 041 (DF Index: 025) | True: 1 | Pred: 1 | Confidence: 0.7232 | Uncertainty (Std): 0.0341
# Sample 042 (DF Index: 006) | True: 1 | Pred: 1 | Confidence: 0.6771 | Uncertainty (Std): 0.0382
# Sample 043 (DF Index: 327) | True: 0 | Pred: 1 | Confidence: 0.8421 | Uncertainty (Std): 0.0583
# Sample 044 (DF Index: 522) | True: 1 | Pred: 1 | Confidence: 0.5205 | Uncertainty (Std): 0.0560
# Sample 045 (DF Index: 215) | True: 0 | Pred: 0 | Confidence: 0.5633 | Uncertainty (Std): 0.0340
# Sample 046 (DF Index: 276) | True: 0 | Pred: 0 | Confidence: 0.8784 | Uncertainty (Std): 0.0678
# Sample 047 (DF Index: 196) | True: 1 | Pred: 0 | Confidence: 0.5753 | Uncertainty (Std): 0.0451
# Sample 048 (DF Index: 050) | True: 0 | Pred: 0 | Confidence: 0.6760 | Uncertainty (Std): 0.0180
# Sample 049 (DF Index: 624) | True: 1 | Pred: 1 | Confidence: 0.8707 | Uncertainty (Std): 0.0290
# Sample 050 (DF Index: 018) | True: 1 | Pred: 0 | Confidence: 0.5275 | Uncertainty (Std): 0.0389
# Sample 051 (DF Index: 367) | True: 0 | Pred: 1 | Confidence: 0.7391 | Uncertainty (Std): 0.0644
# Sample 052 (DF Index: 131) | True: 0 | Pred: 0 | Confidence: 0.6430 | Uncertainty (Std): 0.0146
# Sample 053 (DF Index: 764) | True: 0 | Pred: 0 | Confidence: 0.8378 | Uncertainty (Std): 0.0224
# Sample 054 (DF Index: 924) | True: 0 | Pred: 1 | Confidence: 0.7749 | Uncertainty (Std): 0.0910
# Sample 055 (DF Index: 629) | True: 0 | Pred: 0 | Confidence: 0.6129 | Uncertainty (Std): 0.0373
# Sample 056 (DF Index: 586) | True: 0 | Pred: 1 | Confidence: 0.5207 | Uncertainty (Std): 0.0454
# Sample 057 (DF Index: 638) | True: 1 | Pred: 1 | Confidence: 0.7375 | Uncertainty (Std): 0.0379
# Sample 058 (DF Index: 783) | True: 1 | Pred: 1 | Confidence: 0.8463 | Uncertainty (Std): 0.0647
# Sample 059 (DF Index: 471) | True: 1 | Pred: 0 | Confidence: 0.6837 | Uncertainty (Std): 0.0390
# Sample 060 (DF Index: 600) | True: 1 | Pred: 1 | Confidence: 0.9999 | Uncertainty (Std): 0.0001
# Sample 061 (DF Index: 685) | True: 0 | Pred: 1 | Confidence: 0.8631 | Uncertainty (Std): 0.0424
# Sample 062 (DF Index: 118) | True: 0 | Pred: 0 | Confidence: 0.7009 | Uncertainty (Std): 0.0415
# Sample 063 (DF Index: 482) | True: 1 | Pred: 1 | Confidence: 0.7567 | Uncertainty (Std): 0.0346
# Sample 064 (DF Index: 965) | True: 0 | Pred: 0 | Confidence: 0.7226 | Uncertainty (Std): 0.0294
# Sample 065 (DF Index: 409) | True: 1 | Pred: 1 | Confidence: 0.6197 | Uncertainty (Std): 0.0589
# Sample 066 (DF Index: 319) | True: 0 | Pred: 0 | Confidence: 0.5690 | Uncertainty (Std): 0.0377
# Sample 067 (DF Index: 673) | True: 0 | Pred: 0 | Confidence: 0.6657 | Uncertainty (Std): 0.0462
# Sample 068 (DF Index: 184) | True: 1 | Pred: 1 | Confidence: 0.9997 | Uncertainty (Std): 0.0003
# Sample 069 (DF Index: 849) | True: 1 | Pred: 1 | Confidence: 0.7148 | Uncertainty (Std): 0.0604
# Sample 070 (DF Index: 331) | True: 1 | Pred: 0 | Confidence: 0.5702 | Uncertainty (Std): 0.0338
# Sample 071 (DF Index: 285) | True: 1 | Pred: 1 | Confidence: 0.6960 | Uncertainty (Std): 0.0367
# Sample 072 (DF Index: 047) | True: 0 | Pred: 0 | Confidence: 0.7568 | Uncertainty (Std): 0.0300
# Sample 073 (DF Index: 978) | True: 0 | Pred: 1 | Confidence: 0.7126 | Uncertainty (Std): 0.0456
# Sample 074 (DF Index: 465) | True: 1 | Pred: 1 | Confidence: 0.5930 | Uncertainty (Std): 0.0616
# Sample 075 (DF Index: 454) | True: 0 | Pred: 0 | Confidence: 0.6821 | Uncertainty (Std): 0.0445
# Sample 076 (DF Index: 528) | True: 0 | Pred: 0 | Confidence: 0.6419 | Uncertainty (Std): 0.0428
# Sample 077 (DF Index: 826) | True: 1 | Pred: 1 | Confidence: 0.8972 | Uncertainty (Std): 0.0291
# Sample 078 (DF Index: 502) | True: 0 | Pred: 1 | Confidence: 0.8652 | Uncertainty (Std): 0.0308
# Sample 079 (DF Index: 224) | True: 0 | Pred: 1 | Confidence: 0.9173 | Uncertainty (Std): 0.0261
# Sample 080 (DF Index: 666) | True: 1 | Pred: 0 | Confidence: 0.5476 | Uncertainty (Std): 0.0321
# Sample 081 (DF Index: 993) | True: 0 | Pred: 0 | Confidence: 0.7436 | Uncertainty (Std): 0.0582
# Sample 082 (DF Index: 557) | True: 0 | Pred: 0 | Confidence: 0.9330 | Uncertainty (Std): 0.0126
# Sample 083 (DF Index: 544) | True: 0 | Pred: 0 | Confidence: 0.7691 | Uncertainty (Std): 0.0165
# Sample 084 (DF Index: 408) | True: 0 | Pred: 0 | Confidence: 0.7192 | Uncertainty (Std): 0.0183
# Sample 085 (DF Index: 999) | True: 0 | Pred: 0 | Confidence: 0.8011 | Uncertainty (Std): 0.0551
# Sample 086 (DF Index: 348) | True: 0 | Pred: 0 | Confidence: 0.6261 | Uncertainty (Std): 0.0562
# Sample 087 (DF Index: 123) | True: 0 | Pred: 0 | Confidence: 0.6443 | Uncertainty (Std): 0.0324
# Sample 088 (DF Index: 113) | True: 0 | Pred: 0 | Confidence: 0.5666 | Uncertainty (Std): 0.0440
# Sample 089 (DF Index: 714) | True: 1 | Pred: 1 | Confidence: 0.6519 | Uncertainty (Std): 0.0391
# Sample 090 (DF Index: 404) | True: 0 | Pred: 0 | Confidence: 0.5666 | Uncertainty (Std): 0.0476
# Sample 091 (DF Index: 261) | True: 0 | Pred: 0 | Confidence: 0.6325 | Uncertainty (Std): 0.0186
# Sample 092 (DF Index: 375) | True: 0 | Pred: 0 | Confidence: 0.7775 | Uncertainty (Std): 0.0234
# Sample 093 (DF Index: 381) | True: 1 | Pred: 1 | Confidence: 0.8367 | Uncertainty (Std): 0.1079
# Sample 094 (DF Index: 177) | True: 0 | Pred: 0 | Confidence: 0.5724 | Uncertainty (Std): 0.0222
# Sample 095 (DF Index: 277) | True: 1 | Pred: 1 | Confidence: 0.7161 | Uncertainty (Std): 0.0421
# Sample 096 (DF Index: 724) | True: 1 | Pred: 0 | Confidence: 0.6953 | Uncertainty (Std): 0.0316
# Sample 097 (DF Index: 704) | True: 0 | Pred: 0 | Confidence: 0.8710 | Uncertainty (Std): 0.0173
# Sample 098 (DF Index: 887) | True: 1 | Pred: 1 | Confidence: 0.9056 | Uncertainty (Std): 0.0420
# Sample 099 (DF Index: 504) | True: 1 | Pred: 1 | Confidence: 0.6878 | Uncertainty (Std): 0.0857
#
# Classification metrics (train vs. test):
#                              train      test
# accuracy                     0.788889   0.770000
# auroc                        0.873700   0.791667
# auprc                        0.899889   0.770543
# brier_score                  0.152278   0.195553
# negative_log_likelihood      0.464556   0.623851
# expected_calibration_error   0.251762   0.309037
# tn                           280.000000   37.000000
# fp                           63.000000   11.000000
# fn                           89.000000   12.000000
# tp                           288.000000   40.000000

# %% [markdown]
# ## 14. Train the 1D CNN
