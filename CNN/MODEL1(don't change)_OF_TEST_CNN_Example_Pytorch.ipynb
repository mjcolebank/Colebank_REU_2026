# %% [markdown]
# <a href="https://colab.research.google.com/github/mjcolebank/Colebank_REU_2026/blob/main/CNN/MODEL1(don't%20change)_OF_TEST_CNN_Example_Pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Convolutional Neural Networks in PyTorch
#
# This notebook walks through the application of **convolutional neural networks (CNNs)** using PyTorch.
#
# We will study two examples:
#
# 1. A **2D CNN for image classification** on the MNIST handwritten digit dataset.
# 2. A **1D CNN for time-series classification** on a synthetic signal dataset.
#
# The goal is to mirror the ideas from the NumPy implementation, but now using PyTorch's built-in tools:
#
# - `torch.Tensor`
# - `torch.nn.Module`
# - `torch.nn.Conv2d`
# - `torch.nn.Conv1d`
# - `torch.nn.ReLU`
# - `torch.nn.MaxPool2d`
# - `torch.nn.Linear`
# - `torch.optim`
# - automatic differentiation through `loss.backward()`
#
# PyTorch handles the tedious backpropagation bookkeeping for us, but the mathematical structure is the same as the NumPy version.

# %% [markdown]
# ## 1. What is a Convolutional Neural Network?
#
# A fully connected neural network treats each input feature as separate. For images, this ignores spatial structure. A CNN instead uses **filters**, also called **kernels**, that slide across an input and detect local patterns.
#
# For a 2D image, a convolutional layer learns filters that may detect edges, corners, curves, or other local image features.
#
# For a 1D time series, a convolutional layer learns filters that may detect spikes, oscillations, trends, or short temporal patterns.
#
# A typical CNN layer sequence is:
#
# \[
# \text{Input} \rightarrow \text{Convolution} \rightarrow \text{Activation} \rightarrow \text{Pooling} \rightarrow \text{Dense Layers} \rightarrow \text{Prediction}.
# \]
#
# In PyTorch, these operations are represented as neural network layers.

# %% [markdown]
# ## 2. Imports and Reproducibility
#
# We will use PyTorch for neural network layers and training, NumPy for data generation, and Matplotlib for visualization.

# %%
import numpy as np
import matplotlib.pyplot as plt

import sympy
import sympy.core          # force submodule onto the namespace
import sympy.core.symbol
import torch               # now import torch

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset, random_split

import importlib
sympy.core = importlib.import_module("sympy.core")
sympy.core.symbol = importlib.import_module("sympy.core.symbol")
print(hasattr(sympy, 'core'))

# Optional imports for MNIST.
# If torchvision is not installed, the synthetic time-series example will still run.

try:
    import torchvision
    import torchvision.transforms as transforms
    TORCHVISION_AVAILABLE = True
except ImportError:
    TORCHVISION_AVAILABLE = False

np.random.seed(42)
torch.manual_seed(42) #42

# Use a GPU if available. Otherwise, use CPU.
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# True
# Using device: cuda

# %% [markdown]
# ## 3. Helper Function: Training Loop
#
# The same basic PyTorch training loop will be used for both the image example and the time-series example.
#
# For each epoch:
#
# 1. Load a mini-batch.
# 2. Compute predictions.
# 3. Compute the loss.
# 4. Clear previous gradients.
# 5. Backpropagate using `loss.backward()`.
# 6. Update parameters using the optimizer.
#
# For classification, we will use `nn.CrossEntropyLoss()`. This loss combines:
#
# - a softmax operation, and
# - the negative log-likelihood loss.
#
# Therefore, our models should output raw scores, also called **logits**, not softmax probabilities.

# %%
def train_classifier(model, train_loader, test_loader=None, epochs=5, learning_rate=1e-3, verbose=True):
    # Train a PyTorch classifier using cross-entropy loss.
    model = model.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4)

    history = {
        "train_loss": [],
        "train_acc": [],
        "test_loss": [],
        "test_acc": []
    }

    for epoch in range(epochs):
        model.train()
        total_loss = 0.0
        correct = 0
        total = 0

        for X_batch, y_batch in train_loader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)

            logits = model(X_batch)
            loss = criterion(logits, y_batch)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            batch_size = X_batch.shape[0]
            total_loss += loss.item() * batch_size
            predictions = torch.argmax(logits, dim=1)
            correct += (predictions == y_batch).sum().item()
            total += batch_size

        train_loss = total_loss / total
        train_acc = correct / total
        history["train_loss"].append(train_loss)
        history["train_acc"].append(train_acc)

        if test_loader is not None:
            test_loss, test_acc = evaluate_classifier(model, test_loader, criterion)
            history["test_loss"].append(test_loss)
            history["test_acc"].append(test_acc)

            if verbose:
                print(
                    f"Epoch {epoch + 1}/{epochs}: "
                    f"train loss = {train_loss:.4f}, train acc = {train_acc:.4f}, "
                    f"test loss = {test_loss:.4f}, test acc = {test_acc:.4f}"
                )
        else:
            if verbose:
                print(
                    f"Epoch {epoch + 1}/{epochs}: "
                    f"train loss = {train_loss:.4f}, train acc = {train_acc:.4f}"
                )

    return history


def evaluate_classifier(model, data_loader, criterion=None):
    # Evaluate classification loss and accuracy.
    model.eval()

    if criterion is None:
        criterion = nn.CrossEntropyLoss()

    total_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for X_batch, y_batch in data_loader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)

            logits = model(X_batch)
            loss = criterion(logits, y_batch)

            batch_size = X_batch.shape[0]
            total_loss += loss.item() * batch_size
            predictions = torch.argmax(logits, dim=1)
            correct += (predictions == y_batch).sum().item()
            total += batch_size

    return total_loss / total, correct / total

# %% [markdown]
# ## 4. Helper Function: Plot Training Curves

# %%
def plot_history(history, title="Training History"):
    epochs = np.arange(1, len(history["train_loss"]) + 1)

    plt.figure(figsize=(7, 4))
    plt.plot(epochs, history["train_loss"], label="train loss")
    if len(history["test_loss"]) > 0:
        plt.plot(epochs, history["test_loss"], label="test loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title(title + ": Loss")
    plt.grid(True)
    plt.legend()
    plt.show()

    plt.figure(figsize=(7, 4))
    plt.plot(epochs, history["train_acc"], label="train accuracy")
    if len(history["test_acc"]) > 0:
        plt.plot(epochs, history["test_acc"], label="test accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.title(title + ": Accuracy")
    plt.grid(True)
    plt.legend()
    plt.show()

# %% [markdown]
# # Part II: A 1D CNN for Time-Series Classification
#
# CNNs are not only for images. A 1D CNN can be applied to sequential data such as:
#
# - sensor measurements,
# - financial signals,
# - ECG or EEG recordings,
# - audio waveforms,
# - machine monitoring data,
# - traffic or demand data.
#
# A 1D convolutional layer slides filters along the time axis.
#
# For PyTorch `nn.Conv1d`, the input shape is:
#
# \[
# N \times C \times L,
# \]
#
# where:
#
# - `N` is the batch size,
# - `C` is the number of input channels,
# - `L` is the sequence length.
#
# For a single univariate time series, `C = 1`.

# %% [markdown]
# ## 10. Generate a Synthetic Time-Series Dataset
#
# We will create a three-class time-series classification problem.
#
# Each signal has length 100.
#
# The classes are:
#
# - Class 0: low-frequency sine wave,
# - Class 1: high-frequency sine wave,
# - Class 2: square-wave-like signal.
#
# Noise is added so the classification task is not completely trivial.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.signal import butter, filtfilt, find_peaks

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/REU ECG Analysis
# !ls
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/REU ECG Analysis
# ECG_metrics_1K.npy  ECG_waveforms_1K.npy  EchoNext_EchoData_5K.csv

# %%
from re import X
ECG_data_1K = np.load('ECG_waveforms_1K.npy')
ECG_summary_1K = np.load('ECG_metrics_1K.npy')
Echo_5K = pd.read_csv('EchoNext_EchoData_5K.csv')

labels = Echo_5K['shd_moderate_or_greater_flag']


#initial definitions
negative = labels==0
positive = labels==1
y_ts = np.array(labels[:1000])
X = ECG_data_1K[:1000]
X_ts = np.swapaxes(X, 1, 2)
print(X_ts.shape)
print(y_ts.shape)
# Out:
# (1000, 12, 2500)
# (1000,)

# %% [markdown]
# ## 11. Visualize Example Time Series

# %%
'''
plt.figure(figsize=(10, 5))
for class_label in range(3):
    idx = np.where(y_ts == class_label)[0][0]
    plt.plot(t, X_ts[idx, 0], label=f"Class {class_label}")

plt.xlabel("Time")
plt.ylabel("Signal value")
plt.title("Example Time Series from Each Class")
plt.grid(True)
plt.legend()
plt.show()
'''
# Out:
# '\nplt.figure(figsize=(10, 5))\nfor class_label in range(3):\n    idx = np.where(y_ts == class_label)[0][0]\n    plt.plot(t, X_ts[idx, 0], label=f"Class {class_label}")\n\nplt.xlabel("Time")\nplt.ylabel("Signal value")\nplt.title("Example Time Series from Each Class")\nplt.grid(True)\nplt.legend()\nplt.show()\n'

# %% [markdown]
# ## 12. Create PyTorch DataLoaders for Time Series

# %%
X_ts_tensor = torch.tensor(X_ts, dtype=torch.float32, device = device)
y_ts_tensor = torch.tensor(y_ts, dtype=torch.long, device = device)

ts_dataset = TensorDataset(X_ts_tensor, y_ts_tensor)

train_size = int(0.8 * len(ts_dataset))
test_size = len(ts_dataset) - train_size

ts_train_dataset, ts_test_dataset = random_split(
    ts_dataset,
    [train_size, test_size],
    generator=torch.Generator().manual_seed(42)
)

ts_train_loader = DataLoader(ts_train_dataset, batch_size=32, shuffle=True) #change batch size
batch = next(iter(ts_train_loader))
print(batch[0].shape)

ts_test_loader = DataLoader(ts_test_dataset, batch_size=128, shuffle=False)

print("Time-series training samples:", len(ts_train_dataset))
print("Time-series test samples:", len(ts_test_dataset))
# Out:
# torch.Size([32, 12, 2500])
# Time-series training samples: 800
# Time-series test samples: 200

# %% [markdown]
# ## 13. Define a 1D CNN for Time-Series Classification
#
# This model uses:
#
# 1. `nn.Conv1d(1, 8, kernel_size=5, padding=2)`
# 2. `nn.ReLU()`
# 3. `nn.MaxPool1d(2)`
# 4. `nn.Conv1d(8, 16, kernel_size=5, padding=2)`
# 5. `nn.ReLU()`
# 6. `nn.MaxPool1d(2)`
# 7. Dense classifier layers
#
# The original sequence length is 100.
#
# After the first max pooling layer, the length becomes 50.
#
# After the second max pooling layer, the length becomes 25.
#
# The final convolutional feature tensor has shape:
#
# \[
# 16 \times 25.
# \]

# %%
class TimeSeriesConvNet(nn.Module):
    def __init__(self, sequence_length=2500, num_classes=2, in_channels=12):
        super().__init__()

        self.features = nn.Sequential(
            # Block 1 — compress heavily with large kernel
            nn.Conv1d(in_channels, 8, kernel_size=15, padding=7),
            nn.ReLU(),
            nn.Dropout(0.20),
            nn.MaxPool1d(kernel_size=5),   # 2500 → 500

            # Block 2 — compress again
            nn.Conv1d(8, 12, kernel_size=9, padding=4),
            nn.ReLU(),
            nn.Dropout(0.20),
            nn.MaxPool1d(kernel_size=5),   # 500 → 100

            # Block 3 — final compression
            nn.Conv1d(12, 16, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=5),   # 100 → 20

            # Block 4 — final compression
            nn.Conv1d(16, 20, kernel_size=3, padding=2),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=5),   # 20 → 4


        )

        # 16 filters * 20 timesteps = 320 — much smaller than before (9984)
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(20 * 4, 20),
            nn.ReLU(),
            nn.Linear(20, num_classes),
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x


ts_model = TimeSeriesConvNet(sequence_length=2500, num_classes=2)
print(ts_model)
# Out:
# TimeSeriesConvNet(
#   (features): Sequential(
#     (0): Conv1d(12, 8, kernel_size=(15,), stride=(1,), padding=(7,))
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): MaxPool1d(kernel_size=5, stride=5, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv1d(8, 12, kernel_size=(9,), stride=(1,), padding=(4,))
#     (5): ReLU()
#     (6): Dropout(p=0.2, inplace=False)
#     (7): MaxPool1d(kernel_size=5, stride=5, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv1d(12, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#     (9): ReLU()
#     (10): MaxPool1d(kernel_size=5, stride=5, padding=0, dilation=1, ceil_mode=False)
#     (11): Conv1d(16, 20, kernel_size=(3,), stride=(1,), padding=(2,))
#     (12): ReLU()
#     (13): MaxPool1d(kernel_size=5, stride=5, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=80, out_features=20, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=20, out_features=2, bias=True)
#   )
# )

# %%
print(next(ts_model.parameters()).is_cuda)
# Out:
# True

# %% [markdown]
# ## 14. Train the 1D CNN

# %%
ts_history = train_classifier(
    ts_model,
    ts_train_loader,
    ts_test_loader,
    epochs=1500, #no other num other than 15 works help us
    learning_rate=1e-3,
    verbose=True
)


plot_history(ts_history, title="1D CNN Time-Series Classifier")
# Out:
# Epoch 1/1500: train loss = 0.0893, train acc = 0.9750, test loss = 1.6084, test acc = 0.6750
# Epoch 2/1500: train loss = 0.0203, train acc = 0.9938, test loss = 1.6051, test acc = 0.6600
# Epoch 3/1500: train loss = 0.0165, train acc = 0.9962, test loss = 1.9232, test acc = 0.6750
# Epoch 4/1500: train loss = 0.0467, train acc = 0.9862, test loss = 2.0179, test acc = 0.6650
# Epoch 5/1500: train loss = 0.0335, train acc = 0.9888, test loss = 1.8148, test acc = 0.7050
# Epoch 6/1500: train loss = 0.0886, train acc = 0.9738, test loss = 1.8156, test acc = 0.6300
# Epoch 7/1500: train loss = 0.0207, train acc = 0.9925, test loss = 1.6418, test acc = 0.6800
# Epoch 8/1500: train loss = 0.0090, train acc = 0.9988, test loss = 1.7514, test acc = 0.6450
# Epoch 9/1500: train loss = 0.0202, train acc = 0.9950, test loss = 1.7493, test acc = 0.6700
# Epoch 10/1500: train loss = 0.0207, train acc = 0.9900, test loss = 1.7136, test acc = 0.6650
# Epoch 11/1500: train loss = 0.0187, train acc = 0.9950, test loss = 1.7798, test acc = 0.6550
# Epoch 12/1500: train loss = 0.0112, train acc = 0.9975, test loss = 1.6338, test acc = 0.6850
# Epoch 13/1500: train loss = 0.0173, train acc = 0.9975, test loss = 1.7877, test acc = 0.6750
# Epoch 14/1500: train loss = 0.0305, train acc = 0.9912, test loss = 1.7029, test acc = 0.6700
# Epoch 15/1500: train loss = 0.0454, train acc = 0.9775, test loss = 1.9951, test acc = 0.6450
# Epoch 16/1500: train loss = 0.0944, train acc = 0.9738, test loss = 1.7607, test acc = 0.6700
# Epoch 17/1500: train loss = 0.0506, train acc = 0.9788, test loss = 1.7474, test acc = 0.6650
# Epoch 18/1500: train loss = 0.0356, train acc = 0.9912, test loss = 1.6693, test acc = 0.6950
# Epoch 19/1500: train loss = 0.0362, train acc = 0.9925, test loss = 1.5118, test acc = 0.6650
# Epoch 20/1500: train loss = 0.0159, train acc = 0.9962, test loss = 1.5841, test acc = 0.6700
# Epoch 21/1500: train loss = 0.0147, train acc = 0.9975, test loss = 1.7035, test acc = 0.6600
# Epoch 22/1500: train loss = 0.0299, train acc = 0.9875, test loss = 1.6961, test acc = 0.6750
# Epoch 23/1500: train loss = 0.0625, train acc = 0.9850, test loss = 1.9272, test acc = 0.6400
# Epoch 24/1500: train loss = 0.0181, train acc = 0.9925, test loss = 1.7526, test acc = 0.6750
# Epoch 25/1500: train loss = 0.0219, train acc = 0.9925, test loss = 1.7618, test acc = 0.6500
# Epoch 26/1500: train loss = 0.0163, train acc = 0.9962, test loss = 2.0681, test acc = 0.6350
# Epoch 27/1500: train loss = 0.0768, train acc = 0.9800, test loss = 1.9860, test acc = 0.6450
# Epoch 28/1500: train loss = 0.0820, train acc = 0.9637, test loss = 1.9087, test acc = 0.6450
# Epoch 29/1500: train loss = 0.0605, train acc = 0.9788, test loss = 1.5496, test acc = 0.6600
# Epoch 30/1500: train loss = 0.0284, train acc = 0.9888, test loss = 1.6282, test acc = 0.6900
# Epoch 31/1500: train loss = 0.0493, train acc = 0.9825, test loss = 1.6479, test acc = 0.6600
# Epoch 32/1500: train loss = 0.0250, train acc = 0.9900, test loss = 1.5212, test acc = 0.7250
# Epoch 33/1500: train loss = 0.0135, train acc = 0.9962, test loss = 1.6435, test acc = 0.6700
# Epoch 34/1500: train loss = 0.0053, train acc = 0.9988, test loss = 1.6540, test acc = 0.6750
# Epoch 35/1500: train loss = 0.0235, train acc = 0.9950, test loss = 1.6777, test acc = 0.6850
# Epoch 36/1500: train loss = 0.0179, train acc = 0.9938, test loss = 1.6670, test acc = 0.6800
# Epoch 37/1500: train loss = 0.0116, train acc = 0.9950, test loss = 1.7160, test acc = 0.6800
# Epoch 38/1500: train loss = 0.0217, train acc = 0.9938, test loss = 2.0922, test acc = 0.6300
# Epoch 39/1500: train loss = 0.0115, train acc = 0.9988, test loss = 1.7526, test acc = 0.6650
# Epoch 40/1500: train loss = 0.0174, train acc = 0.9938, test loss = 1.8587, test acc = 0.6650
# Epoch 41/1500: train loss = 0.0060, train acc = 1.0000, test loss = 1.7677, test acc = 0.6750
# Epoch 42/1500: train loss = 0.0145, train acc = 0.9962, test loss = 1.8874, test acc = 0.6750
# Epoch 43/1500: train loss = 0.0191, train acc = 0.9900, test loss = 1.7630, test acc = 0.7050
# Epoch 44/1500: train loss = 0.0137, train acc = 0.9938, test loss = 1.9518, test acc = 0.6900
# Epoch 45/1500: train loss = 0.0189, train acc = 0.9962, test loss = 1.8060, test acc = 0.7200
# Epoch 46/1500: train loss = 0.0110, train acc = 0.9962, test loss = 2.0827, test acc = 0.6650
# Epoch 47/1500: train loss = 0.0336, train acc = 0.9862, test loss = 2.1047, test acc = 0.6750
# Epoch 48/1500: train loss = 0.0462, train acc = 0.9838, test loss = 1.9046, test acc = 0.6950
# Epoch 49/1500: train loss = 0.1615, train acc = 0.9587, test loss = 1.4011, test acc = 0.6950
# Epoch 50/1500: train loss = 0.1529, train acc = 0.9700, test loss = 1.3585, test acc = 0.6600
# Epoch 51/1500: train loss = 0.0950, train acc = 0.9812, test loss = 1.3743, test acc = 0.6250
# Epoch 52/1500: train loss = 0.0388, train acc = 0.9875, test loss = 1.3705, test acc = 0.6550
# Epoch 53/1500: train loss = 0.0198, train acc = 0.9950, test loss = 1.4618, test acc = 0.6650
# Epoch 54/1500: train loss = 0.0192, train acc = 0.9962, test loss = 1.4316, test acc = 0.6950
# Epoch 55/1500: train loss = 0.0335, train acc = 0.9888, test loss = 1.4513, test acc = 0.6750
# Epoch 56/1500: train loss = 0.0178, train acc = 0.9950, test loss = 1.4498, test acc = 0.6600
# Epoch 57/1500: train loss = 0.0279, train acc = 0.9900, test loss = 1.5841, test acc = 0.6250
# Epoch 58/1500: train loss = 0.0286, train acc = 0.9900, test loss = 1.4429, test acc = 0.6850
# Epoch 59/1500: train loss = 0.0253, train acc = 0.9888, test loss = 1.6473, test acc = 0.6600
# Epoch 60/1500: train loss = 0.0080, train acc = 0.9988, test loss = 1.6999, test acc = 0.6800
# Epoch 61/1500: train loss = 0.0107, train acc = 0.9975, test loss = 1.7660, test acc = 0.6700
# Epoch 62/1500: train loss = 0.0156, train acc = 0.9925, test loss = 1.6105, test acc = 0.7050
# Epoch 63/1500: train loss = 0.0089, train acc = 0.9988, test loss = 1.7026, test acc = 0.6700
# Epoch 64/1500: train loss = 0.0041, train acc = 1.0000, test loss = 1.7335, test acc = 0.6700
# Epoch 65/1500: train loss = 0.0067, train acc = 1.0000, test loss = 1.7327, test acc = 0.6800
# Epoch 66/1500: train loss = 0.0055, train acc = 0.9975, test loss = 1.7976, test acc = 0.6800
# Epoch 67/1500: train loss = 0.0107, train acc = 0.9950, test loss = 1.9111, test acc = 0.6700
# Epoch 68/1500: train loss = 0.0105, train acc = 0.9962, test loss = 1.9368, test acc = 0.6650
# Epoch 69/1500: train loss = 0.0163, train acc = 0.9938, test loss = 2.0706, test acc = 0.6550
# Epoch 70/1500: train loss = 0.0419, train acc = 0.9825, test loss = 2.0006, test acc = 0.6600
# Epoch 71/1500: train loss = 0.0425, train acc = 0.9888, test loss = 2.1649, test acc = 0.6350
# Epoch 72/1500: train loss = 0.0405, train acc = 0.9888, test loss = 1.9554, test acc = 0.6450
# Epoch 73/1500: train loss = 0.0091, train acc = 1.0000, test loss = 1.8130, test acc = 0.6600
# Epoch 74/1500: train loss = 0.0220, train acc = 0.9938, test loss = 1.9896, test acc = 0.6450
# Epoch 75/1500: train loss = 0.0370, train acc = 0.9850, test loss = 2.2300, test acc = 0.6800
# Epoch 76/1500: train loss = 0.0721, train acc = 0.9775, test loss = 1.6333, test acc = 0.7000
# Epoch 77/1500: train loss = 0.0830, train acc = 0.9775, test loss = 1.6224, test acc = 0.7100
# Epoch 78/1500: train loss = 0.1114, train acc = 0.9613, test loss = 1.4255, test acc = 0.6950
# Epoch 79/1500: train loss = 0.0441, train acc = 0.9862, test loss = 1.7426, test acc = 0.6850
# Epoch 80/1500: train loss = 0.0306, train acc = 0.9938, test loss = 1.7897, test acc = 0.6450
# Epoch 81/1500: train loss = 0.0123, train acc = 0.9975, test loss = 1.7419, test acc = 0.6900
# Epoch 82/1500: train loss = 0.0107, train acc = 0.9962, test loss = 1.8028, test acc = 0.6750
# Epoch 83/1500: train loss = 0.0111, train acc = 0.9962, test loss = 1.7009, test acc = 0.7050
# Epoch 84/1500: train loss = 0.0034, train acc = 1.0000, test loss = 1.6914, test acc = 0.7000
# Epoch 85/1500: train loss = 0.0052, train acc = 0.9975, test loss = 1.7711, test acc = 0.6850
# Epoch 86/1500: train loss = 0.0043, train acc = 1.0000, test loss = 1.7539, test acc = 0.6750
# Epoch 87/1500: train loss = 0.0068, train acc = 0.9975, test loss = 1.7991, test acc = 0.6650
# Epoch 88/1500: train loss = 0.0033, train acc = 1.0000, test loss = 1.8390, test acc = 0.6700
# Epoch 89/1500: train loss = 0.0026, train acc = 1.0000, test loss = 1.8551, test acc = 0.6600
# Epoch 90/1500: train loss = 0.0104, train acc = 0.9975, test loss = 1.8854, test acc = 0.6900
# Epoch 91/1500: train loss = 0.0046, train acc = 1.0000, test loss = 1.8623, test acc = 0.7050
# Epoch 92/1500: train loss = 0.0056, train acc = 0.9975, test loss = 1.9200, test acc = 0.6750
# Epoch 93/1500: train loss = 0.0076, train acc = 0.9975, test loss = 1.8235, test acc = 0.7050
# Epoch 94/1500: train loss = 0.0087, train acc = 0.9975, test loss = 2.1058, test acc = 0.6700
# Epoch 95/1500: train loss = 0.0138, train acc = 0.9975, test loss = 2.0455, test acc = 0.6650
# Epoch 96/1500: train loss = 0.0295, train acc = 0.9888, test loss = 1.9292, test acc = 0.6500
# Epoch 97/1500: train loss = 0.0120, train acc = 0.9962, test loss = 1.8969, test acc = 0.6600
# Epoch 98/1500: train loss = 0.0131, train acc = 0.9925, test loss = 1.9839, test acc = 0.6700
# Epoch 99/1500: train loss = 0.0249, train acc = 0.9900, test loss = 1.7836, test acc = 0.6900
# Epoch 100/1500: train loss = 0.0233, train acc = 0.9900, test loss = 1.9203, test acc = 0.6850
# Epoch 101/1500: train loss = 0.0915, train acc = 0.9700, test loss = 1.6565, test acc = 0.6650
# Epoch 102/1500: train loss = 0.0849, train acc = 0.9688, test loss = 1.8337, test acc = 0.6400
# Epoch 103/1500: train loss = 0.0525, train acc = 0.9788, test loss = 1.6458, test acc = 0.6700
# Epoch 104/1500: train loss = 0.0351, train acc = 0.9900, test loss = 1.7704, test acc = 0.6800
# Epoch 105/1500: train loss = 0.0145, train acc = 0.9950, test loss = 1.8198, test acc = 0.6800
# Epoch 106/1500: train loss = 0.0135, train acc = 0.9950, test loss = 1.8698, test acc = 0.6750
# Epoch 107/1500: train loss = 0.0078, train acc = 0.9988, test loss = 1.8911, test acc = 0.6850
# Epoch 108/1500: train loss = 0.0642, train acc = 0.9862, test loss = 1.6705, test acc = 0.6800
# Epoch 109/1500: train loss = 0.0271, train acc = 0.9888, test loss = 1.5036, test acc = 0.7300
# Epoch 110/1500: train loss = 0.0308, train acc = 0.9888, test loss = 1.6016, test acc = 0.6800
# Epoch 111/1500: train loss = 0.0881, train acc = 0.9738, test loss = 1.5949, test acc = 0.6900
# Epoch 112/1500: train loss = 0.0534, train acc = 0.9775, test loss = 1.4446, test acc = 0.6950
# Epoch 113/1500: train loss = 0.0184, train acc = 0.9938, test loss = 1.6667, test acc = 0.6600
# Epoch 114/1500: train loss = 0.0106, train acc = 0.9975, test loss = 1.7191, test acc = 0.6750
# Epoch 115/1500: train loss = 0.0074, train acc = 0.9988, test loss = 1.6888, test acc = 0.6800
# Epoch 116/1500: train loss = 0.0090, train acc = 0.9962, test loss = 1.6308, test acc = 0.6900
# Epoch 117/1500: train loss = 0.0078, train acc = 0.9962, test loss = 1.9253, test acc = 0.6700
# Epoch 118/1500: train loss = 0.0115, train acc = 0.9988, test loss = 1.8420, test acc = 0.6900
# Epoch 119/1500: train loss = 0.0049, train acc = 1.0000, test loss = 1.9328, test acc = 0.6850
# Epoch 120/1500: train loss = 0.0076, train acc = 0.9975, test loss = 1.9019, test acc = 0.7000
# Epoch 121/1500: train loss = 0.0093, train acc = 0.9962, test loss = 1.8383, test acc = 0.6950
# Epoch 122/1500: train loss = 0.0080, train acc = 0.9962, test loss = 1.8476, test acc = 0.6850
# Epoch 123/1500: train loss = 0.0040, train acc = 0.9988, test loss = 1.8330, test acc = 0.6950
# Epoch 124/1500: train loss = 0.0022, train acc = 1.0000, test loss = 1.8873, test acc = 0.6800
# Epoch 125/1500: train loss = 0.0179, train acc = 0.9938, test loss = 1.8228, test acc = 0.6800
# Epoch 126/1500: train loss = 0.0083, train acc = 0.9975, test loss = 1.9443, test acc = 0.6850
# Epoch 127/1500: train loss = 0.0094, train acc = 0.9962, test loss = 2.1458, test acc = 0.6700
# Epoch 128/1500: train loss = 0.0132, train acc = 0.9938, test loss = 2.1720, test acc = 0.6800
# Epoch 129/1500: train loss = 0.1276, train acc = 0.9762, test loss = 1.9328, test acc = 0.6650
# Epoch 130/1500: train loss = 0.0904, train acc = 0.9700, test loss = 1.6987, test acc = 0.6600
# Epoch 131/1500: train loss = 0.0113, train acc = 0.9975, test loss = 1.6748, test acc = 0.6800
# Epoch 132/1500: train loss = 0.0146, train acc = 0.9962, test loss = 1.7264, test acc = 0.6800
# Epoch 133/1500: train loss = 0.0093, train acc = 0.9975, test loss = 1.8839, test acc = 0.6750
# Epoch 134/1500: train loss = 0.0091, train acc = 0.9975, test loss = 1.8422, test acc = 0.6900
# Epoch 135/1500: train loss = 0.0070, train acc = 0.9975, test loss = 1.7777, test acc = 0.7000
# Epoch 136/1500: train loss = 0.0218, train acc = 0.9938, test loss = 1.7025, test acc = 0.6900
# Epoch 137/1500: train loss = 0.0186, train acc = 0.9975, test loss = 1.7204, test acc = 0.7000
# Epoch 138/1500: train loss = 0.0142, train acc = 0.9962, test loss = 1.8489, test acc = 0.6650
# Epoch 139/1500: train loss = 0.0070, train acc = 0.9975, test loss = 1.8307, test acc = 0.6850
# Epoch 140/1500: train loss = 0.0276, train acc = 0.9925, test loss = 1.7815, test acc = 0.7000
# Epoch 141/1500: train loss = 0.0470, train acc = 0.9800, test loss = 1.7796, test acc = 0.7050
# Epoch 142/1500: train loss = 0.0644, train acc = 0.9812, test loss = 1.6556, test acc = 0.7050
# Epoch 143/1500: train loss = 0.0119, train acc = 0.9975, test loss = 1.6254, test acc = 0.6800
# Epoch 144/1500: train loss = 0.0060, train acc = 0.9975, test loss = 1.6021, test acc = 0.6850
# Epoch 145/1500: train loss = 0.0153, train acc = 0.9950, test loss = 1.8611, test acc = 0.6750
# Epoch 146/1500: train loss = 0.0049, train acc = 1.0000, test loss = 1.9409, test acc = 0.6750
# Epoch 147/1500: train loss = 0.0085, train acc = 0.9950, test loss = 1.7505, test acc = 0.6900
# Epoch 148/1500: train loss = 0.0078, train acc = 0.9962, test loss = 1.7901, test acc = 0.6950
# Epoch 149/1500: train loss = 0.0028, train acc = 1.0000, test loss = 1.9286, test acc = 0.6650
# Epoch 150/1500: train loss = 0.0014, train acc = 1.0000, test loss = 1.9650, test acc = 0.6600
# Epoch 151/1500: train loss = 0.0019, train acc = 1.0000, test loss = 1.9542, test acc = 0.6700
# Epoch 152/1500: train loss = 0.0031, train acc = 0.9988, test loss = 1.9760, test acc = 0.6900
# Epoch 153/1500: train loss = 0.0075, train acc = 0.9950, test loss = 1.9707, test acc = 0.6700
# Epoch 154/1500: train loss = 0.0083, train acc = 0.9950, test loss = 2.2692, test acc = 0.6650
# Epoch 155/1500: train loss = 0.0451, train acc = 0.9862, test loss = 1.9351, test acc = 0.6850
# Epoch 156/1500: train loss = 0.0441, train acc = 0.9888, test loss = 1.8420, test acc = 0.6950
# Epoch 157/1500: train loss = 0.0426, train acc = 0.9850, test loss = 1.9992, test acc = 0.6700
# Epoch 158/1500: train loss = 0.0142, train acc = 0.9962, test loss = 1.8894, test acc = 0.6800
# Epoch 159/1500: train loss = 0.0145, train acc = 0.9950, test loss = 1.8638, test acc = 0.6850
# Epoch 160/1500: train loss = 0.0059, train acc = 0.9988, test loss = 2.0174, test acc = 0.6900
# Epoch 161/1500: train loss = 0.0062, train acc = 0.9988, test loss = 1.9406, test acc = 0.6850
# Epoch 162/1500: train loss = 0.0056, train acc = 0.9975, test loss = 2.0922, test acc = 0.6600
# Epoch 163/1500: train loss = 0.0071, train acc = 0.9975, test loss = 2.0215, test acc = 0.6850
# Epoch 164/1500: train loss = 0.0017, train acc = 1.0000, test loss = 2.0006, test acc = 0.6850
# Epoch 165/1500: train loss = 0.0037, train acc = 0.9988, test loss = 2.1135, test acc = 0.6600
# Epoch 166/1500: train loss = 0.0213, train acc = 0.9938, test loss = 2.0879, test acc = 0.6750
# Epoch 167/1500: train loss = 0.0093, train acc = 0.9975, test loss = 2.1994, test acc = 0.7050
# Epoch 168/1500: train loss = 0.0081, train acc = 0.9988, test loss = 2.0995, test acc = 0.7150
# Epoch 169/1500: train loss = 0.0294, train acc = 0.9888, test loss = 2.3426, test acc = 0.6600
# Epoch 170/1500: train loss = 0.1347, train acc = 0.9613, test loss = 1.8370, test acc = 0.6100
# Epoch 171/1500: train loss = 0.0619, train acc = 0.9812, test loss = 1.3851, test acc = 0.7150
# Epoch 172/1500: train loss = 0.0335, train acc = 0.9850, test loss = 1.5502, test acc = 0.6800
# Epoch 173/1500: train loss = 0.0163, train acc = 0.9938, test loss = 1.6375, test acc = 0.6950
# Epoch 174/1500: train loss = 0.0240, train acc = 0.9912, test loss = 1.5251, test acc = 0.7050
# Epoch 175/1500: train loss = 0.0282, train acc = 0.9875, test loss = 1.6499, test acc = 0.7150
# Epoch 176/1500: train loss = 0.0394, train acc = 0.9875, test loss = 1.6684, test acc = 0.7000
# Epoch 177/1500: train loss = 0.0153, train acc = 0.9950, test loss = 1.5635, test acc = 0.6800
# Epoch 178/1500: train loss = 0.0098, train acc = 0.9962, test loss = 1.7126, test acc = 0.6750
# Epoch 179/1500: train loss = 0.0047, train acc = 1.0000, test loss = 1.8069, test acc = 0.6850
# Epoch 180/1500: train loss = 0.0049, train acc = 1.0000, test loss = 1.7703, test acc = 0.6750
# Epoch 181/1500: train loss = 0.0127, train acc = 0.9950, test loss = 1.9900, test acc = 0.6700
# Epoch 182/1500: train loss = 0.0272, train acc = 0.9862, test loss = 1.6453, test acc = 0.7100
# Epoch 183/1500: train loss = 0.0240, train acc = 0.9925, test loss = 1.8803, test acc = 0.6800
# Epoch 184/1500: train loss = 0.0348, train acc = 0.9862, test loss = 1.9262, test acc = 0.6750
# Epoch 185/1500: train loss = 0.0257, train acc = 0.9938, test loss = 1.7681, test acc = 0.7200
# Epoch 186/1500: train loss = 0.0254, train acc = 0.9900, test loss = 1.8918, test acc = 0.6750
# Epoch 187/1500: train loss = 0.0083, train acc = 0.9975, test loss = 1.8593, test acc = 0.7050
# Epoch 188/1500: train loss = 0.0159, train acc = 0.9950, test loss = 1.9961, test acc = 0.6900
# Epoch 189/1500: train loss = 0.1020, train acc = 0.9637, test loss = 1.5807, test acc = 0.7050
# Epoch 190/1500: train loss = 0.0369, train acc = 0.9862, test loss = 1.8303, test acc = 0.6650
# Epoch 191/1500: train loss = 0.0387, train acc = 0.9825, test loss = 1.6898, test acc = 0.7450
# Epoch 192/1500: train loss = 0.0253, train acc = 0.9888, test loss = 1.9979, test acc = 0.6600
# Epoch 193/1500: train loss = 0.0314, train acc = 0.9888, test loss = 2.0815, test acc = 0.6800
# Epoch 194/1500: train loss = 0.0232, train acc = 0.9938, test loss = 1.6308, test acc = 0.7050
# Epoch 195/1500: train loss = 0.0192, train acc = 0.9962, test loss = 1.7397, test acc = 0.6850
# Epoch 196/1500: train loss = 0.0077, train acc = 0.9975, test loss = 1.6573, test acc = 0.7150
# Epoch 197/1500: train loss = 0.0070, train acc = 0.9988, test loss = 1.7298, test acc = 0.6850
# Epoch 198/1500: train loss = 0.0191, train acc = 0.9950, test loss = 1.7778, test acc = 0.6650
# Epoch 199/1500: train loss = 0.0188, train acc = 0.9925, test loss = 2.0011, test acc = 0.6750
# Epoch 200/1500: train loss = 0.0079, train acc = 0.9975, test loss = 1.8513, test acc = 0.6900
# Epoch 201/1500: train loss = 0.0216, train acc = 0.9912, test loss = 1.8609, test acc = 0.7100
# Epoch 202/1500: train loss = 0.0159, train acc = 0.9962, test loss = 2.3174, test acc = 0.6600
# Epoch 203/1500: train loss = 0.0170, train acc = 0.9938, test loss = 2.0458, test acc = 0.6800
# Epoch 204/1500: train loss = 0.0200, train acc = 0.9938, test loss = 1.8396, test acc = 0.6650
# Epoch 205/1500: train loss = 0.0217, train acc = 0.9938, test loss = 1.8727, test acc = 0.7050
# Epoch 206/1500: train loss = 0.0121, train acc = 0.9962, test loss = 2.2321, test acc = 0.6700
# Epoch 207/1500: train loss = 0.0132, train acc = 0.9938, test loss = 2.3984, test acc = 0.6700
# Epoch 208/1500: train loss = 0.0071, train acc = 0.9975, test loss = 2.2057, test acc = 0.6700
# Epoch 209/1500: train loss = 0.0028, train acc = 1.0000, test loss = 1.9440, test acc = 0.6900
# Epoch 210/1500: train loss = 0.0073, train acc = 0.9975, test loss = 1.8135, test acc = 0.7100
# Epoch 211/1500: train loss = 0.0063, train acc = 0.9988, test loss = 1.8317, test acc = 0.7250
# Epoch 212/1500: train loss = 0.0151, train acc = 0.9962, test loss = 2.5048, test acc = 0.6700
# Epoch 213/1500: train loss = 0.0272, train acc = 0.9888, test loss = 2.2317, test acc = 0.6800
# Epoch 214/1500: train loss = 0.0103, train acc = 0.9975, test loss = 2.5500, test acc = 0.6450
# Epoch 215/1500: train loss = 0.0047, train acc = 0.9988, test loss = 2.1131, test acc = 0.6800
# Epoch 216/1500: train loss = 0.0085, train acc = 0.9962, test loss = 2.1524, test acc = 0.7200
# Epoch 217/1500: train loss = 0.0147, train acc = 0.9962, test loss = 2.2418, test acc = 0.6650
# Epoch 218/1500: train loss = 0.0119, train acc = 0.9938, test loss = 1.8222, test acc = 0.7100
# Epoch 219/1500: train loss = 0.0058, train acc = 1.0000, test loss = 1.9488, test acc = 0.7200
# Epoch 220/1500: train loss = 0.0049, train acc = 0.9988, test loss = 2.0250, test acc = 0.7200
# Epoch 221/1500: train loss = 0.0108, train acc = 0.9962, test loss = 2.1320, test acc = 0.7000
# Epoch 222/1500: train loss = 0.0179, train acc = 0.9925, test loss = 1.9921, test acc = 0.7200
# Epoch 223/1500: train loss = 0.0199, train acc = 0.9962, test loss = 1.9805, test acc = 0.6950
# Epoch 224/1500: train loss = 0.0065, train acc = 0.9988, test loss = 1.8046, test acc = 0.6950
# Epoch 225/1500: train loss = 0.0045, train acc = 1.0000, test loss = 1.7739, test acc = 0.7150
# Epoch 226/1500: train loss = 0.0054, train acc = 0.9988, test loss = 1.8097, test acc = 0.7150
# Epoch 227/1500: train loss = 0.0175, train acc = 0.9950, test loss = 2.0008, test acc = 0.7200
# Epoch 228/1500: train loss = 0.0142, train acc = 0.9950, test loss = 2.4086, test acc = 0.6800
# Epoch 229/1500: train loss = 0.0050, train acc = 1.0000, test loss = 2.2615, test acc = 0.6650
# Epoch 230/1500: train loss = 0.0022, train acc = 1.0000, test loss = 2.2454, test acc = 0.6750
# Epoch 231/1500: train loss = 0.0138, train acc = 0.9962, test loss = 2.2124, test acc = 0.6950
# Epoch 232/1500: train loss = 0.0152, train acc = 0.9962, test loss = 2.1421, test acc = 0.6650
# Epoch 233/1500: train loss = 0.0431, train acc = 0.9838, test loss = 2.1452, test acc = 0.6900
# Epoch 234/1500: train loss = 0.0328, train acc = 0.9912, test loss = 2.0981, test acc = 0.7250
# Epoch 235/1500: train loss = 0.0766, train acc = 0.9825, test loss = 2.4901, test acc = 0.6700
# Epoch 236/1500: train loss = 0.0838, train acc = 0.9750, test loss = 1.8542, test acc = 0.6900
# Epoch 237/1500: train loss = 0.0324, train acc = 0.9900, test loss = 1.7039, test acc = 0.7150
# Epoch 238/1500: train loss = 0.0208, train acc = 0.9962, test loss = 1.6392, test acc = 0.7100
# Epoch 239/1500: train loss = 0.0447, train acc = 0.9850, test loss = 1.8812, test acc = 0.6700
# Epoch 240/1500: train loss = 0.0605, train acc = 0.9812, test loss = 1.6462, test acc = 0.6950
# Epoch 241/1500: train loss = 0.0103, train acc = 0.9975, test loss = 1.6713, test acc = 0.7100
# Epoch 242/1500: train loss = 0.0152, train acc = 0.9962, test loss = 1.6598, test acc = 0.7050
# Epoch 243/1500: train loss = 0.0085, train acc = 0.9988, test loss = 1.6250, test acc = 0.7300
# Epoch 244/1500: train loss = 0.0067, train acc = 0.9988, test loss = 1.7566, test acc = 0.7000
# Epoch 245/1500: train loss = 0.0021, train acc = 1.0000, test loss = 1.7761, test acc = 0.7050
# Epoch 246/1500: train loss = 0.0015, train acc = 1.0000, test loss = 1.8610, test acc = 0.7000
# Epoch 247/1500: train loss = 0.0097, train acc = 0.9988, test loss = 1.8326, test acc = 0.6950
# Epoch 248/1500: train loss = 0.0119, train acc = 0.9950, test loss = 1.6680, test acc = 0.7300
# Epoch 249/1500: train loss = 0.0270, train acc = 0.9925, test loss = 2.1969, test acc = 0.7100
# Epoch 250/1500: train loss = 0.0151, train acc = 0.9950, test loss = 1.8963, test acc = 0.7250
# Epoch 251/1500: train loss = 0.0258, train acc = 0.9925, test loss = 1.8213, test acc = 0.7200
# Epoch 252/1500: train loss = 0.0078, train acc = 0.9962, test loss = 1.9129, test acc = 0.6700
# Epoch 253/1500: train loss = 0.0176, train acc = 0.9950, test loss = 1.6730, test acc = 0.7050
# Epoch 254/1500: train loss = 0.0123, train acc = 0.9962, test loss = 1.9279, test acc = 0.6850
# Epoch 255/1500: train loss = 0.0033, train acc = 0.9988, test loss = 1.8935, test acc = 0.7150
# Epoch 256/1500: train loss = 0.0253, train acc = 0.9938, test loss = 1.8055, test acc = 0.7300
# Epoch 257/1500: train loss = 0.0112, train acc = 0.9975, test loss = 1.7107, test acc = 0.7450
# Epoch 258/1500: train loss = 0.0110, train acc = 0.9950, test loss = 2.0565, test acc = 0.7000
# Epoch 259/1500: train loss = 0.0061, train acc = 0.9988, test loss = 2.0035, test acc = 0.7000
# Epoch 260/1500: train loss = 0.0040, train acc = 1.0000, test loss = 1.8965, test acc = 0.6950
# Epoch 261/1500: train loss = 0.0030, train acc = 0.9988, test loss = 2.0249, test acc = 0.7000
# Epoch 262/1500: train loss = 0.0092, train acc = 0.9988, test loss = 1.9400, test acc = 0.6750
# Epoch 263/1500: train loss = 0.0037, train acc = 1.0000, test loss = 2.1724, test acc = 0.6850
# Epoch 264/1500: train loss = 0.0097, train acc = 0.9950, test loss = 2.3500, test acc = 0.6950
# Epoch 265/1500: train loss = 0.0140, train acc = 0.9962, test loss = 2.1239, test acc = 0.7300
# Epoch 266/1500: train loss = 0.0130, train acc = 0.9950, test loss = 2.1534, test acc = 0.7000
# Epoch 267/1500: train loss = 0.0147, train acc = 0.9962, test loss = 2.1477, test acc = 0.7150
# Epoch 268/1500: train loss = 0.0113, train acc = 0.9962, test loss = 1.9441, test acc = 0.7150
# Epoch 269/1500: train loss = 0.0276, train acc = 0.9900, test loss = 2.2350, test acc = 0.6750
# Epoch 270/1500: train loss = 0.0684, train acc = 0.9800, test loss = 2.5406, test acc = 0.6450
# Epoch 271/1500: train loss = 0.0313, train acc = 0.9888, test loss = 1.8476, test acc = 0.6750
# Epoch 272/1500: train loss = 0.0099, train acc = 0.9975, test loss = 1.8086, test acc = 0.6900
# Epoch 273/1500: train loss = 0.0084, train acc = 0.9975, test loss = 1.8424, test acc = 0.6850
# Epoch 274/1500: train loss = 0.0128, train acc = 0.9938, test loss = 1.8122, test acc = 0.7100
# Epoch 275/1500: train loss = 0.0042, train acc = 1.0000, test loss = 1.7649, test acc = 0.7350
# Epoch 276/1500: train loss = 0.0097, train acc = 0.9975, test loss = 2.1173, test acc = 0.6950
# Epoch 277/1500: train loss = 0.0105, train acc = 0.9962, test loss = 2.3639, test acc = 0.6750
# Epoch 278/1500: train loss = 0.0281, train acc = 0.9925, test loss = 1.9194, test acc = 0.7100
# Epoch 279/1500: train loss = 0.0148, train acc = 0.9950, test loss = 1.7234, test acc = 0.7100
# Epoch 280/1500: train loss = 0.0104, train acc = 0.9988, test loss = 1.7567, test acc = 0.7050
# Epoch 281/1500: train loss = 0.0268, train acc = 0.9912, test loss = 1.9090, test acc = 0.7250
# Epoch 282/1500: train loss = 0.0375, train acc = 0.9900, test loss = 2.0040, test acc = 0.6950
# Epoch 283/1500: train loss = 0.0968, train acc = 0.9675, test loss = 1.7035, test acc = 0.6700
# Epoch 284/1500: train loss = 0.0444, train acc = 0.9862, test loss = 1.6475, test acc = 0.7000
# Epoch 285/1500: train loss = 0.0363, train acc = 0.9875, test loss = 2.0145, test acc = 0.6750
# Epoch 286/1500: train loss = 0.0184, train acc = 0.9938, test loss = 1.6104, test acc = 0.7300
# Epoch 287/1500: train loss = 0.0067, train acc = 0.9975, test loss = 1.6599, test acc = 0.7300
# Epoch 288/1500: train loss = 0.0124, train acc = 0.9975, test loss = 1.7611, test acc = 0.7000
# Epoch 289/1500: train loss = 0.0064, train acc = 0.9988, test loss = 1.9242, test acc = 0.6900
# Epoch 290/1500: train loss = 0.0157, train acc = 0.9950, test loss = 1.8769, test acc = 0.6950
# Epoch 291/1500: train loss = 0.0108, train acc = 0.9950, test loss = 2.2020, test acc = 0.6800
# Epoch 292/1500: train loss = 0.0075, train acc = 0.9962, test loss = 2.5405, test acc = 0.6700
# Epoch 293/1500: train loss = 0.0076, train acc = 0.9988, test loss = 2.3593, test acc = 0.6950
# Epoch 294/1500: train loss = 0.0040, train acc = 0.9988, test loss = 2.2810, test acc = 0.6850
# Epoch 295/1500: train loss = 0.0029, train acc = 1.0000, test loss = 2.1194, test acc = 0.6850
# Epoch 296/1500: train loss = 0.0116, train acc = 0.9962, test loss = 2.1195, test acc = 0.7000
# Epoch 297/1500: train loss = 0.0039, train acc = 1.0000, test loss = 2.0970, test acc = 0.6850
# Epoch 298/1500: train loss = 0.0040, train acc = 0.9988, test loss = 2.3160, test acc = 0.6750
# Epoch 299/1500: train loss = 0.0036, train acc = 0.9988, test loss = 1.9611, test acc = 0.6950
# Epoch 300/1500: train loss = 0.0051, train acc = 0.9975, test loss = 1.9614, test acc = 0.7250
# Epoch 301/1500: train loss = 0.0132, train acc = 0.9975, test loss = 2.0478, test acc = 0.6950
# Epoch 302/1500: train loss = 0.0068, train acc = 0.9975, test loss = 2.1227, test acc = 0.6800
# Epoch 303/1500: train loss = 0.0638, train acc = 0.9838, test loss = 1.8136, test acc = 0.6800
# Epoch 304/1500: train loss = 0.1013, train acc = 0.9750, test loss = 1.3974, test acc = 0.6800
# Epoch 305/1500: train loss = 0.0623, train acc = 0.9812, test loss = 1.3733, test acc = 0.7000
# Epoch 306/1500: train loss = 0.0416, train acc = 0.9862, test loss = 1.6881, test acc = 0.6800
# Epoch 307/1500: train loss = 0.0184, train acc = 0.9925, test loss = 1.3661, test acc = 0.6800
# Epoch 308/1500: train loss = 0.0200, train acc = 0.9925, test loss = 1.4808, test acc = 0.6900
# Epoch 309/1500: train loss = 0.0066, train acc = 0.9988, test loss = 1.4611, test acc = 0.6850
# Epoch 310/1500: train loss = 0.0062, train acc = 0.9975, test loss = 1.5064, test acc = 0.6850
# Epoch 311/1500: train loss = 0.0033, train acc = 1.0000, test loss = 1.5048, test acc = 0.7100
# Epoch 312/1500: train loss = 0.0084, train acc = 0.9950, test loss = 1.6653, test acc = 0.7000
# Epoch 313/1500: train loss = 0.0054, train acc = 0.9988, test loss = 1.4994, test acc = 0.7050
# Epoch 314/1500: train loss = 0.0028, train acc = 0.9988, test loss = 1.5868, test acc = 0.7000
# Epoch 315/1500: train loss = 0.0085, train acc = 0.9962, test loss = 1.8526, test acc = 0.7050
# Epoch 316/1500: train loss = 0.0031, train acc = 1.0000, test loss = 2.0479, test acc = 0.6900
# Epoch 317/1500: train loss = 0.0317, train acc = 0.9888, test loss = 1.7681, test acc = 0.6750
# Epoch 318/1500: train loss = 0.0144, train acc = 0.9950, test loss = 1.5545, test acc = 0.7050
# Epoch 319/1500: train loss = 0.0256, train acc = 0.9912, test loss = 2.0448, test acc = 0.6650
# Epoch 320/1500: train loss = 0.0442, train acc = 0.9862, test loss = 2.1725, test acc = 0.6750
# Epoch 321/1500: train loss = 0.0413, train acc = 0.9862, test loss = 1.5861, test acc = 0.7200
# Epoch 322/1500: train loss = 0.0111, train acc = 0.9975, test loss = 1.8056, test acc = 0.6650
# Epoch 323/1500: train loss = 0.0091, train acc = 0.9975, test loss = 1.8436, test acc = 0.6750
# Epoch 324/1500: train loss = 0.0053, train acc = 0.9988, test loss = 1.8458, test acc = 0.7050
# Epoch 325/1500: train loss = 0.0047, train acc = 0.9975, test loss = 1.8524, test acc = 0.6950
# Epoch 326/1500: train loss = 0.0160, train acc = 0.9925, test loss = 2.1779, test acc = 0.7000
# Epoch 327/1500: train loss = 0.0484, train acc = 0.9812, test loss = 2.1774, test acc = 0.6650
# Epoch 328/1500: train loss = 0.0143, train acc = 0.9975, test loss = 1.9870, test acc = 0.7050
# Epoch 329/1500: train loss = 0.0128, train acc = 0.9962, test loss = 1.9796, test acc = 0.6900
# Epoch 330/1500: train loss = 0.0077, train acc = 0.9962, test loss = 1.9232, test acc = 0.6900
# Epoch 331/1500: train loss = 0.0106, train acc = 0.9950, test loss = 1.9495, test acc = 0.7000
# Epoch 332/1500: train loss = 0.0123, train acc = 0.9975, test loss = 2.0390, test acc = 0.6750
# Epoch 333/1500: train loss = 0.0165, train acc = 0.9950, test loss = 1.9540, test acc = 0.6900
# Epoch 334/1500: train loss = 0.0024, train acc = 1.0000, test loss = 2.0358, test acc = 0.6900
# Epoch 335/1500: train loss = 0.0032, train acc = 0.9988, test loss = 2.0169, test acc = 0.7150
# Epoch 336/1500: train loss = 0.0052, train acc = 0.9988, test loss = 2.0346, test acc = 0.6750
# Epoch 337/1500: train loss = 0.0032, train acc = 1.0000, test loss = 1.9912, test acc = 0.7150
# Epoch 338/1500: train loss = 0.0058, train acc = 0.9988, test loss = 2.3436, test acc = 0.6900
# Epoch 339/1500: train loss = 0.1831, train acc = 0.9613, test loss = 2.1840, test acc = 0.6500
# Epoch 340/1500: train loss = 0.2124, train acc = 0.9337, test loss = 1.2630, test acc = 0.7350
# Epoch 341/1500: train loss = 0.0375, train acc = 0.9875, test loss = 1.2178, test acc = 0.7250
# Epoch 342/1500: train loss = 0.0246, train acc = 0.9900, test loss = 1.4229, test acc = 0.6950
# Epoch 343/1500: train loss = 0.0251, train acc = 0.9888, test loss = 1.4645, test acc = 0.7100
# Epoch 344/1500: train loss = 0.0385, train acc = 0.9875, test loss = 1.4983, test acc = 0.7150
# Epoch 345/1500: train loss = 0.0273, train acc = 0.9925, test loss = 1.3431, test acc = 0.7150
# Epoch 346/1500: train loss = 0.0109, train acc = 0.9950, test loss = 1.3962, test acc = 0.7050
# Epoch 347/1500: train loss = 0.0217, train acc = 0.9925, test loss = 1.4356, test acc = 0.7050
# Epoch 348/1500: train loss = 0.0191, train acc = 0.9938, test loss = 1.5356, test acc = 0.7200
# Epoch 349/1500: train loss = 0.0093, train acc = 0.9975, test loss = 1.6225, test acc = 0.7000
# Epoch 350/1500: train loss = 0.0028, train acc = 1.0000, test loss = 1.6656, test acc = 0.7050
# Epoch 351/1500: train loss = 0.0052, train acc = 0.9988, test loss = 1.7456, test acc = 0.7100
# Epoch 352/1500: train loss = 0.0044, train acc = 0.9988, test loss = 1.7052, test acc = 0.7250
# Epoch 353/1500: train loss = 0.0098, train acc = 0.9975, test loss = 1.6702, test acc = 0.7150
# Epoch 354/1500: train loss = 0.0021, train acc = 1.0000, test loss = 1.8108, test acc = 0.7200
# Epoch 355/1500: train loss = 0.0061, train acc = 0.9975, test loss = 1.7690, test acc = 0.7150
# Epoch 356/1500: train loss = 0.0047, train acc = 0.9975, test loss = 1.8189, test acc = 0.7250
# Epoch 357/1500: train loss = 0.0033, train acc = 1.0000, test loss = 1.8289, test acc = 0.7150
# Epoch 358/1500: train loss = 0.0019, train acc = 1.0000, test loss = 1.9026, test acc = 0.7150
# Epoch 359/1500: train loss = 0.0074, train acc = 0.9988, test loss = 1.9443, test acc = 0.7100
# Epoch 360/1500: train loss = 0.0119, train acc = 0.9962, test loss = 2.0109, test acc = 0.7350
# Epoch 361/1500: train loss = 0.0036, train acc = 1.0000, test loss = 2.0355, test acc = 0.7200
# Epoch 362/1500: train loss = 0.0033, train acc = 0.9988, test loss = 2.0398, test acc = 0.7250
# Epoch 363/1500: train loss = 0.0023, train acc = 1.0000, test loss = 2.0463, test acc = 0.7100
# Epoch 364/1500: train loss = 0.0018, train acc = 1.0000, test loss = 2.1148, test acc = 0.7150
# Epoch 365/1500: train loss = 0.0094, train acc = 0.9950, test loss = 2.1447, test acc = 0.6700
# Epoch 366/1500: train loss = 0.0027, train acc = 1.0000, test loss = 1.9959, test acc = 0.6950
# Epoch 367/1500: train loss = 0.0010, train acc = 1.0000, test loss = 2.0180, test acc = 0.7000
# Epoch 368/1500: train loss = 0.0014, train acc = 1.0000, test loss = 2.0795, test acc = 0.6850
# Epoch 369/1500: train loss = 0.0004, train acc = 1.0000, test loss = 2.1131, test acc = 0.6850
# Epoch 370/1500: train loss = 0.0007, train acc = 1.0000, test loss = 2.1323, test acc = 0.7000
# Epoch 371/1500: train loss = 0.0005, train acc = 1.0000, test loss = 2.1588, test acc = 0.6900
# Epoch 372/1500: train loss = 0.0004, train acc = 1.0000, test loss = 2.1788, test acc = 0.6900
# Epoch 373/1500: train loss = 0.0004, train acc = 1.0000, test loss = 2.1453, test acc = 0.6950
# Epoch 374/1500: train loss = 0.0004, train acc = 1.0000, test loss = 2.1452, test acc = 0.6900
# Epoch 375/1500: train loss = 0.0012, train acc = 1.0000, test loss = 2.1733, test acc = 0.7000
# Epoch 376/1500: train loss = 0.0003, train acc = 1.0000, test loss = 2.1899, test acc = 0.7050
# Epoch 377/1500: train loss = 0.0115, train acc = 0.9975, test loss = 2.2214, test acc = 0.7050
# Epoch 378/1500: train loss = 0.0168, train acc = 0.9925, test loss = 2.0823, test acc = 0.7050
# Epoch 379/1500: train loss = 0.0039, train acc = 0.9988, test loss = 2.1302, test acc = 0.7000
# Epoch 380/1500: train loss = 0.0035, train acc = 0.9988, test loss = 2.2111, test acc = 0.6850
# Epoch 381/1500: train loss = 0.0028, train acc = 1.0000, test loss = 2.3103, test acc = 0.6850
# Epoch 382/1500: train loss = 0.0005, train acc = 1.0000, test loss = 2.3604, test acc = 0.6900
# Epoch 383/1500: train loss = 0.0069, train acc = 0.9975, test loss = 2.3530, test acc = 0.6900
# Epoch 384/1500: train loss = 0.0145, train acc = 0.9950, test loss = 2.1926, test acc = 0.6950
# Epoch 385/1500: train loss = 0.0191, train acc = 0.9975, test loss = 2.0702, test acc = 0.6900
# Epoch 386/1500: train loss = 0.0030, train acc = 1.0000, test loss = 2.1074, test acc = 0.7100
# Epoch 387/1500: train loss = 0.0041, train acc = 1.0000, test loss = 2.1106, test acc = 0.7250
# Epoch 388/1500: train loss = 0.0174, train acc = 0.9938, test loss = 2.3266, test acc = 0.7150
# Epoch 389/1500: train loss = 0.1681, train acc = 0.9525, test loss = 1.6231, test acc = 0.6500
# Epoch 390/1500: train loss = 0.0433, train acc = 0.9850, test loss = 1.4321, test acc = 0.6700
# Epoch 391/1500: train loss = 0.0304, train acc = 0.9900, test loss = 1.6226, test acc = 0.6850
# Epoch 392/1500: train loss = 0.0477, train acc = 0.9862, test loss = 1.5913, test acc = 0.6950
# Epoch 393/1500: train loss = 0.0513, train acc = 0.9838, test loss = 1.7777, test acc = 0.7000
# Epoch 394/1500: train loss = 0.0359, train acc = 0.9875, test loss = 1.7445, test acc = 0.6650
# Epoch 395/1500: train loss = 0.0432, train acc = 0.9862, test loss = 1.8012, test acc = 0.7100
# Epoch 396/1500: train loss = 0.0096, train acc = 0.9962, test loss = 1.6240, test acc = 0.7000
# Epoch 397/1500: train loss = 0.0062, train acc = 0.9975, test loss = 1.7696, test acc = 0.6850
# Epoch 398/1500: train loss = 0.0028, train acc = 1.0000, test loss = 1.7913, test acc = 0.6850
# Epoch 399/1500: train loss = 0.0020, train acc = 1.0000, test loss = 1.8098, test acc = 0.7000
# Epoch 400/1500: train loss = 0.0033, train acc = 1.0000, test loss = 1.8362, test acc = 0.6850
# Epoch 401/1500: train loss = 0.0063, train acc = 0.9962, test loss = 1.9836, test acc = 0.6800
# Epoch 402/1500: train loss = 0.0375, train acc = 0.9900, test loss = 1.6692, test acc = 0.6950
# Epoch 403/1500: train loss = 0.0524, train acc = 0.9875, test loss = 1.6308, test acc = 0.6900
# Epoch 404/1500: train loss = 0.0203, train acc = 0.9912, test loss = 1.6995, test acc = 0.6850
# Epoch 405/1500: train loss = 0.0059, train acc = 1.0000, test loss = 1.8237, test acc = 0.6850
# Epoch 406/1500: train loss = 0.0076, train acc = 0.9975, test loss = 1.9943, test acc = 0.6950
# Epoch 407/1500: train loss = 0.0087, train acc = 0.9975, test loss = 2.2029, test acc = 0.6950
# Epoch 408/1500: train loss = 0.0021, train acc = 1.0000, test loss = 2.1027, test acc = 0.6850
# Epoch 409/1500: train loss = 0.0012, train acc = 1.0000, test loss = 2.0234, test acc = 0.6750
# Epoch 410/1500: train loss = 0.0037, train acc = 0.9988, test loss = 2.1699, test acc = 0.6700
# Epoch 411/1500: train loss = 0.0025, train acc = 0.9988, test loss = 2.0518, test acc = 0.6750
# Epoch 412/1500: train loss = 0.0083, train acc = 0.9962, test loss = 2.1494, test acc = 0.6650
# Epoch 413/1500: train loss = 0.0241, train acc = 0.9938, test loss = 1.9374, test acc = 0.7150
# Epoch 414/1500: train loss = 0.0161, train acc = 0.9912, test loss = 1.7155, test acc = 0.7200
# Epoch 415/1500: train loss = 0.0164, train acc = 0.9950, test loss = 1.8033, test acc = 0.6950
# Epoch 416/1500: train loss = 0.0031, train acc = 0.9988, test loss = 1.7997, test acc = 0.7000
# Epoch 417/1500: train loss = 0.0041, train acc = 0.9988, test loss = 1.7923, test acc = 0.6950
# Epoch 418/1500: train loss = 0.0008, train acc = 1.0000, test loss = 1.8303, test acc = 0.6950
# Epoch 419/1500: train loss = 0.0097, train acc = 0.9962, test loss = 1.8386, test acc = 0.7150
# Epoch 420/1500: train loss = 0.0016, train acc = 1.0000, test loss = 1.8684, test acc = 0.7150
# Epoch 421/1500: train loss = 0.0081, train acc = 0.9962, test loss = 1.9893, test acc = 0.7000
# Epoch 422/1500: train loss = 0.0019, train acc = 1.0000, test loss = 1.9490, test acc = 0.7050
# Epoch 423/1500: train loss = 0.0046, train acc = 0.9975, test loss = 2.0210, test acc = 0.7200
# Epoch 424/1500: train loss = 0.0052, train acc = 0.9988, test loss = 2.0933, test acc = 0.7250
# Epoch 425/1500: train loss = 0.0038, train acc = 0.9988, test loss = 2.0820, test acc = 0.7150
# Epoch 426/1500: train loss = 0.0067, train acc = 0.9988, test loss = 2.0035, test acc = 0.7150
# Epoch 427/1500: train loss = 0.0119, train acc = 0.9950, test loss = 2.4137, test acc = 0.7000
# Epoch 428/1500: train loss = 0.0122, train acc = 0.9962, test loss = 2.4130, test acc = 0.6800
# Epoch 429/1500: train loss = 0.0013, train acc = 1.0000, test loss = 2.2244, test acc = 0.7100
# Epoch 430/1500: train loss = 0.0154, train acc = 0.9962, test loss = 2.3489, test acc = 0.7150
# Epoch 431/1500: train loss = 0.0030, train acc = 1.0000, test loss = 2.3575, test acc = 0.7050
# Epoch 432/1500: train loss = 0.0188, train acc = 0.9938, test loss = 2.4787, test acc = 0.6950
# Epoch 433/1500: train loss = 0.0173, train acc = 0.9912, test loss = 2.0367, test acc = 0.7100
# Epoch 434/1500: train loss = 0.0177, train acc = 0.9925, test loss = 2.2038, test acc = 0.6950
# Epoch 435/1500: train loss = 0.0466, train acc = 0.9900, test loss = 1.7512, test acc = 0.7050
# Epoch 436/1500: train loss = 0.0791, train acc = 0.9800, test loss = 2.1288, test acc = 0.6400
# Epoch 437/1500: train loss = 0.0220, train acc = 0.9938, test loss = 1.9029, test acc = 0.6750
# Epoch 438/1500: train loss = 0.0144, train acc = 0.9962, test loss = 2.1084, test acc = 0.6500
# Epoch 439/1500: train loss = 0.0062, train acc = 0.9975, test loss = 2.1125, test acc = 0.6600
# Epoch 440/1500: train loss = 0.0019, train acc = 1.0000, test loss = 2.2170, test acc = 0.6500
# Epoch 441/1500: train loss = 0.0076, train acc = 0.9975, test loss = 2.0866, test acc = 0.6700
# Epoch 442/1500: train loss = 0.0140, train acc = 0.9950, test loss = 2.1080, test acc = 0.6600
# Epoch 443/1500: train loss = 0.0521, train acc = 0.9838, test loss = 1.8762, test acc = 0.6400
# Epoch 444/1500: train loss = 0.0459, train acc = 0.9838, test loss = 1.8543, test acc = 0.6450
# Epoch 445/1500: train loss = 0.0434, train acc = 0.9850, test loss = 1.6917, test acc = 0.6900
# Epoch 446/1500: train loss = 0.0295, train acc = 0.9900, test loss = 1.5617, test acc = 0.7100
# Epoch 447/1500: train loss = 0.0316, train acc = 0.9888, test loss = 1.3922, test acc = 0.7150
# Epoch 448/1500: train loss = 0.0243, train acc = 0.9900, test loss = 1.4874, test acc = 0.6850
# Epoch 449/1500: train loss = 0.0047, train acc = 1.0000, test loss = 1.7080, test acc = 0.6700
# Epoch 450/1500: train loss = 0.0059, train acc = 0.9988, test loss = 1.7451, test acc = 0.6750
# Epoch 451/1500: train loss = 0.0048, train acc = 0.9988, test loss = 1.8081, test acc = 0.6800
# Epoch 452/1500: train loss = 0.0052, train acc = 0.9975, test loss = 2.0734, test acc = 0.6750
# Epoch 453/1500: train loss = 0.0038, train acc = 0.9988, test loss = 1.8480, test acc = 0.6950
# Epoch 454/1500: train loss = 0.0051, train acc = 0.9975, test loss = 1.9700, test acc = 0.6900
# Epoch 455/1500: train loss = 0.0014, train acc = 1.0000, test loss = 1.8276, test acc = 0.6850
# Epoch 456/1500: train loss = 0.0013, train acc = 1.0000, test loss = 1.9999, test acc = 0.6900
# Epoch 457/1500: train loss = 0.0103, train acc = 0.9962, test loss = 2.2940, test acc = 0.6750
# Epoch 458/1500: train loss = 0.0256, train acc = 0.9912, test loss = 1.9124, test acc = 0.6850
# Epoch 459/1500: train loss = 0.0116, train acc = 0.9962, test loss = 2.1589, test acc = 0.6750
# Epoch 460/1500: train loss = 0.0207, train acc = 0.9925, test loss = 1.7085, test acc = 0.7050
# Epoch 461/1500: train loss = 0.0219, train acc = 0.9950, test loss = 1.7919, test acc = 0.7100
# Epoch 462/1500: train loss = 0.0146, train acc = 0.9938, test loss = 1.5672, test acc = 0.7300
# Epoch 463/1500: train loss = 0.0092, train acc = 0.9975, test loss = 1.7633, test acc = 0.7100
# Epoch 464/1500: train loss = 0.0094, train acc = 0.9962, test loss = 2.1253, test acc = 0.6900
# Epoch 465/1500: train loss = 0.0071, train acc = 0.9962, test loss = 1.6806, test acc = 0.7300
# Epoch 466/1500: train loss = 0.0191, train acc = 0.9938, test loss = 2.4189, test acc = 0.6650
# Epoch 467/1500: train loss = 0.0679, train acc = 0.9800, test loss = 1.5905, test acc = 0.7250
# Epoch 468/1500: train loss = 0.0525, train acc = 0.9800, test loss = 1.7008, test acc = 0.6750
# Epoch 469/1500: train loss = 0.0122, train acc = 0.9962, test loss = 1.5071, test acc = 0.6850
# Epoch 470/1500: train loss = 0.0058, train acc = 0.9988, test loss = 1.9619, test acc = 0.6800
# Epoch 471/1500: train loss = 0.0276, train acc = 0.9875, test loss = 1.8012, test acc = 0.7050
# Epoch 472/1500: train loss = 0.0382, train acc = 0.9850, test loss = 2.5640, test acc = 0.6600
# Epoch 473/1500: train loss = 0.0918, train acc = 0.9738, test loss = 1.3038, test acc = 0.7350
# Epoch 474/1500: train loss = 0.0246, train acc = 0.9962, test loss = 1.3622, test acc = 0.7350
# Epoch 475/1500: train loss = 0.0103, train acc = 0.9962, test loss = 1.5907, test acc = 0.7250
# Epoch 476/1500: train loss = 0.0152, train acc = 0.9962, test loss = 1.6935, test acc = 0.7350
# Epoch 477/1500: train loss = 0.0217, train acc = 0.9900, test loss = 1.8435, test acc = 0.7150
# Epoch 478/1500: train loss = 0.0085, train acc = 0.9975, test loss = 1.7799, test acc = 0.7250
# Epoch 479/1500: train loss = 0.0017, train acc = 1.0000, test loss = 1.8807, test acc = 0.7250
# Epoch 480/1500: train loss = 0.0074, train acc = 0.9988, test loss = 1.9921, test acc = 0.7150
# Epoch 481/1500: train loss = 0.0037, train acc = 0.9988, test loss = 2.0225, test acc = 0.7050
# Epoch 482/1500: train loss = 0.0026, train acc = 1.0000, test loss = 2.1261, test acc = 0.7350
# Epoch 483/1500: train loss = 0.0058, train acc = 0.9975, test loss = 2.0525, test acc = 0.7200
# Epoch 484/1500: train loss = 0.0061, train acc = 0.9975, test loss = 2.1975, test acc = 0.7150
# Epoch 485/1500: train loss = 0.0033, train acc = 0.9988, test loss = 2.2523, test acc = 0.7150
# Epoch 486/1500: train loss = 0.0011, train acc = 1.0000, test loss = 2.2118, test acc = 0.7200
# Epoch 487/1500: train loss = 0.0056, train acc = 0.9975, test loss = 2.2397, test acc = 0.7150
# Epoch 488/1500: train loss = 0.0161, train acc = 0.9925, test loss = 2.4667, test acc = 0.6900
# Epoch 489/1500: train loss = 0.0524, train acc = 0.9750, test loss = 1.8786, test acc = 0.7100
# Epoch 490/1500: train loss = 0.0198, train acc = 0.9912, test loss = 2.0204, test acc = 0.7300
# Epoch 491/1500: train loss = 0.0124, train acc = 0.9950, test loss = 1.9378, test acc = 0.7250
# Epoch 492/1500: train loss = 0.0057, train acc = 0.9988, test loss = 1.8898, test acc = 0.7250
# Epoch 493/1500: train loss = 0.0037, train acc = 0.9988, test loss = 2.0991, test acc = 0.7250
# Epoch 494/1500: train loss = 0.0060, train acc = 0.9975, test loss = 2.0705, test acc = 0.7250
# Epoch 495/1500: train loss = 0.0101, train acc = 0.9975, test loss = 1.9920, test acc = 0.7300
# Epoch 496/1500: train loss = 0.0091, train acc = 0.9962, test loss = 1.9872, test acc = 0.6950
# Epoch 497/1500: train loss = 0.0091, train acc = 0.9975, test loss = 1.9465, test acc = 0.7100
# Epoch 498/1500: train loss = 0.0112, train acc = 0.9950, test loss = 1.9584, test acc = 0.7150
# Epoch 499/1500: train loss = 0.0062, train acc = 0.9988, test loss = 1.9814, test acc = 0.7250
# Epoch 500/1500: train loss = 0.0054, train acc = 0.9975, test loss = 2.0703, test acc = 0.7200
# Epoch 501/1500: train loss = 0.0030, train acc = 0.9988, test loss = 2.1090, test acc = 0.7150
# Epoch 502/1500: train loss = 0.0015, train acc = 1.0000, test loss = 2.2453, test acc = 0.7100
# Epoch 503/1500: train loss = 0.0025, train acc = 0.9988, test loss = 2.1968, test acc = 0.7100
# Epoch 504/1500: train loss = 0.0020, train acc = 0.9988, test loss = 2.2199, test acc = 0.7000
# Epoch 505/1500: train loss = 0.0061, train acc = 0.9988, test loss = 2.1487, test acc = 0.7300
# Epoch 506/1500: train loss = 0.0117, train acc = 0.9962, test loss = 1.9393, test acc = 0.7250
# ...
# Epoch 1126/1500: train loss = 0.0035, train acc = 0.9988, test loss = 1.8602, test acc = 0.7500
# Epoch 1127/1500: train loss = 0.0043, train acc = 0.9988, test loss = 2.2582, test acc = 0.7150
# Epoch 1128/1500: train loss = 0.0008, train acc = 1.0000, test loss = 2.1863, test acc = 0.7300
# Epoch 1129/1500: train loss = 0.0171, train acc = 0.9962, test loss = 2.0647, test acc = 0.7300
# Epoch 1130/1500: train loss = 0.0009, train acc = 1.0000, test loss = 2.1558, test acc = 0.7300
# Epoch 1131/1500: train loss = 0.0025, train acc = 0.9988, test loss = 2.0464, test acc = 0.7300
# Epoch 1132/1500: train loss = 0.0034, train acc = 0.9975, test loss = 2.5472, test acc = 0.7000
# Epoch 1133/1500: train loss = 0.0448, train acc = 0.9838, test loss = 1.8980, test acc = 0.7150
# Epoch 1134/1500: train loss = 0.0197, train acc = 0.9925, test loss = 1.6790, test acc = 0.7050
# Epoch 1135/1500: train loss = 0.0076, train acc = 0.9988, test loss = 1.7307, test acc = 0.7100
# Epoch 1136/1500: train loss = 0.0044, train acc = 0.9988, test loss = 1.7246, test acc = 0.7100
# Epoch 1137/1500: train loss = 0.0031, train acc = 0.9988, test loss = 1.8588, test acc = 0.7150
# Epoch 1138/1500: train loss = 0.0011, train acc = 1.0000, test loss = 1.8678, test acc = 0.7150
# Epoch 1139/1500: train loss = 0.0130, train acc = 0.9962, test loss = 1.7335, test acc = 0.7300
# Epoch 1140/1500: train loss = 0.0057, train acc = 0.9988, test loss = 2.3180, test acc = 0.6800
# Epoch 1141/1500: train loss = 0.0161, train acc = 0.9950, test loss = 1.9784, test acc = 0.6900
# Epoch 1142/1500: train loss = 0.0077, train acc = 0.9962, test loss = 1.6203, test acc = 0.7350
# Epoch 1143/1500: train loss = 0.0097, train acc = 0.9962, test loss = 2.1724, test acc = 0.6800
# Epoch 1144/1500: train loss = 0.0040, train acc = 0.9988, test loss = 1.7435, test acc = 0.7200
# Epoch 1145/1500: train loss = 0.0073, train acc = 0.9962, test loss = 1.8728, test acc = 0.7100
# Epoch 1146/1500: train loss = 0.0044, train acc = 0.9988, test loss = 2.8424, test acc = 0.6750
# Epoch 1147/1500: train loss = 0.0012, train acc = 1.0000, test loss = 2.0340, test acc = 0.7250
# Epoch 1148/1500: train loss = 0.0007, train acc = 1.0000, test loss = 2.1652, test acc = 0.7250
# Epoch 1149/1500: train loss = 0.0027, train acc = 0.9988, test loss = 2.3353, test acc = 0.7150
# Epoch 1150/1500: train loss = 0.0020, train acc = 1.0000, test loss = 2.3736, test acc = 0.7200
# Epoch 1151/1500: train loss = 0.0008, train acc = 1.0000, test loss = 2.1343, test acc = 0.7250
# Epoch 1152/1500: train loss = 0.0121, train acc = 0.9950, test loss = 1.9364, test acc = 0.7000
# Epoch 1153/1500: train loss = 0.0341, train acc = 0.9888, test loss = 2.0623, test acc = 0.7200
# Epoch 1154/1500: train loss = 0.0321, train acc = 0.9925, test loss = 1.9624, test acc = 0.7000
# Epoch 1155/1500: train loss = 0.0102, train acc = 0.9950, test loss = 2.0345, test acc = 0.7300
# Epoch 1156/1500: train loss = 0.0008, train acc = 1.0000, test loss = 2.2547, test acc = 0.7100
# Epoch 1157/1500: train loss = 0.0009, train acc = 1.0000, test loss = 2.2657, test acc = 0.7050
# Epoch 1158/1500: train loss = 0.0020, train acc = 1.0000, test loss = 2.2702, test acc = 0.7300
# Epoch 1159/1500: train loss = 0.0008, train acc = 1.0000, test loss = 2.2256, test acc = 0.7300
# Epoch 1160/1500: train loss = 0.0002, train acc = 1.0000, test loss = 2.2266, test acc = 0.7450
# Epoch 1161/1500: train loss = 0.0006, train acc = 1.0000, test loss = 2.2787, test acc = 0.7250
# Epoch 1162/1500: train loss = 0.0006, train acc = 1.0000, test loss = 2.2523, test acc = 0.7400
# Epoch 1163/1500: train loss = 0.0005, train acc = 1.0000, test loss = 2.3545, test acc = 0.7350
# Epoch 1164/1500: train loss = 0.0002, train acc = 1.0000, test loss = 2.4585, test acc = 0.7200
# Epoch 1165/1500: train loss = 0.0005, train acc = 1.0000, test loss = 2.4646, test acc = 0.7200
# Epoch 1166/1500: train loss = 0.0002, train acc = 1.0000, test loss = 2.4580, test acc = 0.7200
# Epoch 1167/1500: train loss = 0.0002, train acc = 1.0000, test loss = 2.4708, test acc = 0.7200
# Epoch 1168/1500: train loss = 0.0152, train acc = 0.9950, test loss = 2.5993, test acc = 0.7000
# Epoch 1169/1500: train loss = 0.0035, train acc = 0.9988, test loss = 2.1926, test acc = 0.7250
# Epoch 1170/1500: train loss = 0.0400, train acc = 0.9900, test loss = 2.2679, test acc = 0.6900
# Epoch 1171/1500: train loss = 0.0149, train acc = 0.9938, test loss = 2.0026, test acc = 0.6850
# Epoch 1172/1500: train loss = 0.0084, train acc = 0.9975, test loss = 2.0855, test acc = 0.6950
# Epoch 1173/1500: train loss = 0.0019, train acc = 1.0000, test loss = 2.2605, test acc = 0.7050
# Epoch 1174/1500: train loss = 0.0020, train acc = 1.0000, test loss = 2.2201, test acc = 0.6950
# Epoch 1175/1500: train loss = 0.0014, train acc = 1.0000, test loss = 2.8340, test acc = 0.7100
# Epoch 1176/1500: train loss = 0.0066, train acc = 0.9975, test loss = 2.4193, test acc = 0.6900
# Epoch 1177/1500: train loss = 0.0339, train acc = 0.9912, test loss = 2.0116, test acc = 0.7100
# Epoch 1178/1500: train loss = 0.0587, train acc = 0.9862, test loss = 1.7536, test acc = 0.7100
# Epoch 1179/1500: train loss = 0.0085, train acc = 0.9975, test loss = 1.4306, test acc = 0.7150
# Epoch 1180/1500: train loss = 0.0080, train acc = 0.9962, test loss = 1.6878, test acc = 0.7150
# Epoch 1181/1500: train loss = 0.0040, train acc = 1.0000, test loss = 1.8957, test acc = 0.7000
# Epoch 1182/1500: train loss = 0.0013, train acc = 1.0000, test loss = 1.8155, test acc = 0.7200
# Epoch 1183/1500: train loss = 0.0024, train acc = 0.9988, test loss = 1.8400, test acc = 0.7150
# Epoch 1184/1500: train loss = 0.0005, train acc = 1.0000, test loss = 1.8770, test acc = 0.7000
# Epoch 1185/1500: train loss = 0.0011, train acc = 1.0000, test loss = 2.0531, test acc = 0.7250
# Epoch 1186/1500: train loss = 0.0020, train acc = 0.9988, test loss = 1.9103, test acc = 0.7000
# Epoch 1187/1500: train loss = 0.0029, train acc = 0.9988, test loss = 1.9500, test acc = 0.7100
# Epoch 1188/1500: train loss = 0.0060, train acc = 0.9975, test loss = 1.8760, test acc = 0.7350
# Epoch 1189/1500: train loss = 0.0234, train acc = 0.9925, test loss = 1.6426, test acc = 0.7000
# Epoch 1190/1500: train loss = 0.0036, train acc = 0.9988, test loss = 1.9087, test acc = 0.6800
# Epoch 1191/1500: train loss = 0.0019, train acc = 1.0000, test loss = 1.8489, test acc = 0.6700
# Epoch 1192/1500: train loss = 0.0010, train acc = 1.0000, test loss = 1.8916, test acc = 0.6700
# Epoch 1193/1500: train loss = 0.0015, train acc = 0.9988, test loss = 1.8872, test acc = 0.6750
# Epoch 1194/1500: train loss = 0.0078, train acc = 0.9975, test loss = 2.3512, test acc = 0.7050
# Epoch 1195/1500: train loss = 0.0027, train acc = 0.9988, test loss = 2.1877, test acc = 0.7000
# Epoch 1196/1500: train loss = 0.0063, train acc = 0.9975, test loss = 1.8922, test acc = 0.7100
# Epoch 1197/1500: train loss = 0.0046, train acc = 0.9975, test loss = 2.0240, test acc = 0.6950
# Epoch 1198/1500: train loss = 0.0018, train acc = 1.0000, test loss = 1.7881, test acc = 0.7350
# Epoch 1199/1500: train loss = 0.0010, train acc = 1.0000, test loss = 1.9812, test acc = 0.7200
# Epoch 1200/1500: train loss = 0.0077, train acc = 0.9975, test loss = 1.8416, test acc = 0.6900
# Epoch 1201/1500: train loss = 0.0087, train acc = 0.9962, test loss = 2.2420, test acc = 0.6850
# Epoch 1202/1500: train loss = 0.0113, train acc = 0.9950, test loss = 1.9097, test acc = 0.7100
# Epoch 1203/1500: train loss = 0.0104, train acc = 0.9975, test loss = 2.3324, test acc = 0.6950
# Epoch 1204/1500: train loss = 0.0026, train acc = 1.0000, test loss = 2.0320, test acc = 0.7100
# Epoch 1205/1500: train loss = 0.0035, train acc = 0.9975, test loss = 2.1998, test acc = 0.6950
# Epoch 1206/1500: train loss = 0.0053, train acc = 0.9975, test loss = 2.3952, test acc = 0.7000
# Epoch 1207/1500: train loss = 0.0010, train acc = 1.0000, test loss = 2.4201, test acc = 0.7000
# Epoch 1208/1500: train loss = 0.0135, train acc = 0.9975, test loss = 2.4716, test acc = 0.7000
# Epoch 1209/1500: train loss = 0.0262, train acc = 0.9900, test loss = 2.5568, test acc = 0.6850
# Epoch 1210/1500: train loss = 0.0301, train acc = 0.9912, test loss = 2.7340, test acc = 0.6750
# Epoch 1211/1500: train loss = 0.0257, train acc = 0.9925, test loss = 1.9657, test acc = 0.7150
# Epoch 1212/1500: train loss = 0.0221, train acc = 0.9938, test loss = 1.7880, test acc = 0.7150
# Epoch 1213/1500: train loss = 0.0088, train acc = 0.9962, test loss = 2.1906, test acc = 0.7000
# Epoch 1214/1500: train loss = 0.0026, train acc = 0.9988, test loss = 1.7944, test acc = 0.6950
# Epoch 1215/1500: train loss = 0.0013, train acc = 1.0000, test loss = 1.9273, test acc = 0.6950
# Epoch 1216/1500: train loss = 0.0026, train acc = 1.0000, test loss = 1.9995, test acc = 0.7050
# Epoch 1217/1500: train loss = 0.0039, train acc = 0.9988, test loss = 1.9700, test acc = 0.7150
# Epoch 1218/1500: train loss = 0.0124, train acc = 0.9988, test loss = 2.3713, test acc = 0.6850
# Epoch 1219/1500: train loss = 0.0095, train acc = 0.9962, test loss = 2.8006, test acc = 0.6700
# Epoch 1220/1500: train loss = 0.0417, train acc = 0.9875, test loss = 2.6448, test acc = 0.6700
# Epoch 1221/1500: train loss = 0.0403, train acc = 0.9862, test loss = 2.1681, test acc = 0.6500
# Epoch 1222/1500: train loss = 0.0402, train acc = 0.9925, test loss = 1.7415, test acc = 0.7000
# Epoch 1223/1500: train loss = 0.0051, train acc = 0.9988, test loss = 1.6511, test acc = 0.7200
# Epoch 1224/1500: train loss = 0.0080, train acc = 0.9962, test loss = 1.9673, test acc = 0.6800
# Epoch 1225/1500: train loss = 0.0040, train acc = 0.9988, test loss = 1.9277, test acc = 0.6850
# Epoch 1226/1500: train loss = 0.0031, train acc = 0.9988, test loss = 2.1253, test acc = 0.6850
# Epoch 1227/1500: train loss = 0.0067, train acc = 0.9988, test loss = 1.8498, test acc = 0.6950
# Epoch 1228/1500: train loss = 0.0082, train acc = 0.9962, test loss = 1.8353, test acc = 0.7000
# Epoch 1229/1500: train loss = 0.0028, train acc = 0.9988, test loss = 2.0102, test acc = 0.6900
# Epoch 1230/1500: train loss = 0.0039, train acc = 0.9988, test loss = 1.8111, test acc = 0.7050
# Epoch 1231/1500: train loss = 0.0024, train acc = 0.9988, test loss = 1.9883, test acc = 0.7100
# Epoch 1232/1500: train loss = 0.0010, train acc = 1.0000, test loss = 1.9168, test acc = 0.7300
# Epoch 1233/1500: train loss = 0.0143, train acc = 0.9962, test loss = 2.2901, test acc = 0.6950
# Epoch 1234/1500: train loss = 0.0051, train acc = 1.0000, test loss = 1.7994, test acc = 0.7100
# Epoch 1235/1500: train loss = 0.0020, train acc = 0.9988, test loss = 1.9345, test acc = 0.7000
# Epoch 1236/1500: train loss = 0.0004, train acc = 1.0000, test loss = 1.8807, test acc = 0.6900
# Epoch 1237/1500: train loss = 0.0004, train acc = 1.0000, test loss = 1.9173, test acc = 0.6950
# Epoch 1238/1500: train loss = 0.0018, train acc = 0.9988, test loss = 2.2253, test acc = 0.7150
# Epoch 1239/1500: train loss = 0.0007, train acc = 1.0000, test loss = 2.0752, test acc = 0.7150
# Epoch 1240/1500: train loss = 0.0013, train acc = 0.9988, test loss = 2.1760, test acc = 0.7000
# Epoch 1241/1500: train loss = 0.0009, train acc = 1.0000, test loss = 2.2482, test acc = 0.7000
# Epoch 1242/1500: train loss = 0.0030, train acc = 1.0000, test loss = 2.4001, test acc = 0.7050
# Epoch 1243/1500: train loss = 0.0111, train acc = 0.9950, test loss = 2.4009, test acc = 0.7000
# Epoch 1244/1500: train loss = 0.0072, train acc = 0.9975, test loss = 2.7162, test acc = 0.6700
# Epoch 1245/1500: train loss = 0.0043, train acc = 0.9988, test loss = 1.9693, test acc = 0.6900
# Epoch 1246/1500: train loss = 0.0084, train acc = 0.9975, test loss = 2.0926, test acc = 0.6900
# Epoch 1247/1500: train loss = 0.0080, train acc = 0.9988, test loss = 2.1705, test acc = 0.7250
# Epoch 1248/1500: train loss = 0.0007, train acc = 1.0000, test loss = 1.9858, test acc = 0.7400
# Epoch 1249/1500: train loss = 0.0012, train acc = 1.0000, test loss = 2.0487, test acc = 0.7250
# Epoch 1250/1500: train loss = 0.0012, train acc = 1.0000, test loss = 2.3089, test acc = 0.7200
# Epoch 1251/1500: train loss = 0.0008, train acc = 1.0000, test loss = 2.2381, test acc = 0.7100
# Epoch 1252/1500: train loss = 0.0019, train acc = 1.0000, test loss = 2.2510, test acc = 0.7150
# Epoch 1253/1500: train loss = 0.0007, train acc = 1.0000, test loss = 2.3108, test acc = 0.7150
# Epoch 1254/1500: train loss = 0.0002, train acc = 1.0000, test loss = 2.1890, test acc = 0.7150
# Epoch 1255/1500: train loss = 0.0002, train acc = 1.0000, test loss = 2.2368, test acc = 0.7200
# Epoch 1256/1500: train loss = 0.0045, train acc = 0.9988, test loss = 2.5797, test acc = 0.7150
# Epoch 1257/1500: train loss = 0.0867, train acc = 0.9812, test loss = 2.9595, test acc = 0.6600
# Epoch 1258/1500: train loss = 0.0605, train acc = 0.9800, test loss = 1.3131, test acc = 0.7350
# Epoch 1259/1500: train loss = 0.0264, train acc = 0.9875, test loss = 1.6477, test acc = 0.6950
# Epoch 1260/1500: train loss = 0.0065, train acc = 0.9975, test loss = 1.8996, test acc = 0.6900
# Epoch 1261/1500: train loss = 0.0058, train acc = 0.9975, test loss = 1.7453, test acc = 0.7150
# Epoch 1262/1500: train loss = 0.0080, train acc = 0.9975, test loss = 1.7850, test acc = 0.6850
# Epoch 1263/1500: train loss = 0.0026, train acc = 1.0000, test loss = 1.8633, test acc = 0.6600
# Epoch 1264/1500: train loss = 0.0008, train acc = 1.0000, test loss = 1.9963, test acc = 0.6750
# Epoch 1265/1500: train loss = 0.0006, train acc = 1.0000, test loss = 2.0046, test acc = 0.6800
# Epoch 1266/1500: train loss = 0.0079, train acc = 0.9975, test loss = 1.9580, test acc = 0.6900
# Epoch 1267/1500: train loss = 0.0018, train acc = 1.0000, test loss = 1.9780, test acc = 0.6900
# Epoch 1268/1500: train loss = 0.0009, train acc = 1.0000, test loss = 2.0141, test acc = 0.6900
# Epoch 1269/1500: train loss = 0.0008, train acc = 1.0000, test loss = 2.0911, test acc = 0.6900
# Epoch 1270/1500: train loss = 0.0017, train acc = 0.9988, test loss = 2.5833, test acc = 0.7000
# Epoch 1271/1500: train loss = 0.0016, train acc = 0.9988, test loss = 2.0880, test acc = 0.6950
# Epoch 1272/1500: train loss = 0.0006, train acc = 1.0000, test loss = 2.0955, test acc = 0.6950
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1159/4091599414.py in <cell line: 0>()
# ----> 1 ts_history = train_classifier(
#       2     ts_model,
#       3     ts_train_loader,
#       4     ts_test_loader,
#       5     epochs=1500, #no other num other than 15 works help us
#
# /tmp/ipykernel_1159/759720808.py in train_classifier(model, train_loader, test_loader, epochs, learning_rate, verbose)
#      26
#      27             optimizer.zero_grad()
# ---> 28             loss.backward()
#      29             optimizer.step()
#      30
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     629                 inputs=inputs,
#     630             )
# --> 631         torch.autograd.backward(
#     632             self, gradient, retain_graph, create_graph, inputs=inputs
#     633         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     379     # some Python versions print out the first line of a multi-line function
#     380     # calls in the traceback and some print out the last line
# --> 381     _engine_run_backward(
#     382         tensors,
#     383         grad_tensors_,
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     867         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     868     try:
# --> 869         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     870             t_outputs, *args, **kwargs
#     871         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %% [markdown]
# ## 15. Inspect Time-Series Predictions

# %%
ts_model.eval()

X_batch, y_batch = next(iter(ts_test_loader))

with torch.no_grad():
    logits = ts_model(X_batch.to(device))
    predictions = torch.argmax(logits, dim=1).cpu()

plt.figure(figsize=(12, 8))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.plot(X_batch[i, 0].numpy())
    plt.title(f"True: {y_batch[i].item()}, Pred: {predictions[i].item()}")
    plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 16. Optional: Visualize Learned 1D Filters
#
# The first convolutional layer learns small time-domain filters. Each filter has length 5 in this example.
#
# These learned filters can be thought of as small pattern detectors.

# %%
'''
first_conv = ts_model.features[0]
filters = first_conv.weight.detach().cpu().numpy()

plt.figure(figsize=(10, 6))
for i in range(filters.shape[0]):
    plt.subplot(2, 4, i + 1)
    plt.plot(filters[i, 0])
    plt.title(f"Filter {i}")
    plt.grid(True)

plt.tight_layout()
plt.show()
'''
# Out:
# '\nfirst_conv = ts_model.features[0]\nfilters = first_conv.weight.detach().cpu().numpy()\n\nplt.figure(figsize=(10, 6))\nfor i in range(filters.shape[0]):\n    plt.subplot(2, 4, i + 1)\n    plt.plot(filters[i, 0])\n    plt.title(f"Filter {i}")\n    plt.grid(True)\n\nplt.tight_layout()\nplt.show()\n'

# %% [markdown]
# # Summary
#
# This notebook showed two applications of convolutional neural networks in PyTorch.
#
# ## 2D CNN for MNIST
#
# A 2D CNN uses filters that slide across image height and width. This is useful for image data because nearby pixels contain meaningful local structure.
#
# ## 1D CNN for Time Series
#
# A 1D CNN uses filters that slide along the time axis. This is useful for detecting short temporal patterns such as oscillations, spikes, jumps, or repeated motifs.
#
# ## Key PyTorch Ideas
#
# The most important PyTorch components were:
#
# - `nn.Conv2d` for image convolution,
# - `nn.Conv1d` for time-series convolution,
# - `nn.ReLU` for nonlinear activation,
# - `nn.MaxPool2d` and `nn.MaxPool1d` for downsampling,
# - `nn.Linear` for dense classification layers,
# - `nn.CrossEntropyLoss` for multiclass classification,
# - `loss.backward()` for automatic backpropagation,
# - `torch.optim.Adam` for parameter updates.
#
# Compared with the NumPy implementation, PyTorch makes the neural network code much shorter because it handles gradients automatically.
